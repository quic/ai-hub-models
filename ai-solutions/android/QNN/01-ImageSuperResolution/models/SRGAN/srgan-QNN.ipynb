# %% [markdown]
# # Setting Up All Artifacts details

# %%
import os
os.environ['QNN_SDK_ROOT']="/local/mnt/workspace/gokul/QNN/2.19.0.240124" #set up your qnn path here.
os.environ['ANDROID_NDK_ROOT']="/local/mnt/workspace/gokul/android-ndk-r25c"
os.environ['RAW_FILE_FOLDER']="input/raw"
os.environ['MODEL_NAME']="srgan_fp32"
os.environ['QUANTIZED_MODEL_NAME']="srgan_w8a8"
os.environ['MODEL_PATH']="models/srgan_fp32"
os.environ['QUANTIZED_MODEL_PATH']="models/srgan_w8a8"
os.environ['TARGET_INPUT_LIST']="input/input.txt"
os.environ['ONDEVICE_FOLDER']="srgan"
os.environ['DEVICE_HOST']="localhost"
os.environ['DEVICE_ID']="bc468c1d" #fill your device-id. Use command "adb devices" to get devices names. example :"e18d5d0"
os.environ['QNN_TARGET_ARCH']="aarch64-android"
os.environ['QNN_TARGET_STL']="libQnnHtp.so"

# %%
# %%bash
# git clone https://github.com/andreas128/mmsr.git
# Out:
# Cloning into 'mmsr'...

# %%
# %%bash
# cd mmsr
# git reset --hard a73b318f0f07feb6505ef5cb1abf0db33e33807a
# Out:
# HEAD is now at a73b318 Merge pull request #32 from imPRAGMA/master

# %%
# %%bash
# cd mmsr
# git apply ../mmsr-changes.patch
# Out:
# ../mmsr-changes.patch:61: trailing whitespace.
#     pass
# warning: 1 line adds whitespace errors.

# %%
# %%bash
# git clone https://github.com/quic/aimet-model-zoo/
# cp -r srgan.patch aimet-model-zoo
# cd aimet-model-zoo
# git apply srgan.patch
# Out:
# Cloning into 'aimet-model-zoo'...
# srgan.patch:34: trailing whitespace.
#
# warning: 1 line adds whitespace errors.

# %% [markdown]
# ## Steps to generate ONNX model

# %%
# %%bash
# cp -r aimet-model-zoo/aimet_zoo_torch/srgan/evaluators/srgan_quanteval.py mmsr/
# rm -rf aimet-model-zoo/

# %%
# %%bash
# cd mmsr/codes/
# touch __init__.py

# %%
# %%bash
# cd mmsr/
# python srgan_quanteval.py --mmsr-path '../mmsr'
# Out:
# download complete!
# configuration complete!
# Parsing file ./codes/options/test/test_SRGAN.yml...
# export CUDA_VISIBLE_DEVICES=0
# Loading test images...

# %%
import cv2
import glob
import os
import numpy as np
import torch
from math import ceil, floor

# %%
os.makedirs('models', exist_ok= True)
os.makedirs('output', exist_ok= True)

# %%
# %%bash
# cp -r mmsr/srgan.onnx models/

# %% [markdown]
# # Download dataset
# <ul>
#     <li>  Dataset link wget https://figshare.com/ndownloader/files/38256855  </li>
# <li>Below block will automatically download datsest, but in case if it fails please download from above link.</li>
#     <li> Recommended, to comment below code, if already downloaded dataset once.</li>
#     <ul>

# %%
# %%bash
# wget https://figshare.com/ndownloader/files/38256855
# unzip 38256855 -d input
# rm -rf 38256855
# rm -rf input/Set14/image_SRF_4
# rm -rf input/Set14/image_SRF_3
# mkdir input/raw
# find input/Set14/image_SRF_2 -name '*_LR*' -delete
# mv input/Set14/image_SRF_2/* input/Set14/
# rm -rf input/Set14/image_SRF_2/
# Out:
# --2024-04-03 13:33:12--  https://figshare.com/ndownloader/files/38256855
# Resolving figshare.com (figshare.com)... 2a05:d018:1f4:d003:5b0f:933e:fd1f:bb37, 2a05:d018:1f4:d000:917e:3a38:2abb:9b0, 54.76.53.103, ...
# Connecting to figshare.com (figshare.com)|2a05:d018:1f4:d003:5b0f:933e:fd1f:bb37|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files
#  'input/Set14/img_012_SRF_2_HR.png',
#  'input/Set14/img_013_SRF_2_HR.png',
#  'input/Set14/img_014_SRF_2_HR.png']

# %%
import requests

url = 'https://raw.githubusercontent.com/quic/aimet-model-zoo/develop/aimet_zoo_torch/common/super_resolution/imresize.py'
response = requests.get(url)

if response.status_code == 200:
    with open('imresize.py', 'wb') as f:
        f.write(response.content)
        print('done')
else:
    print("error")
# Out:
# done

# %%
RGB_WEIGHTS = torch.FloatTensor([65.481, 128.553, 24.966])
from imresize import *
def preprocess(img, scaling_factor=2):
    lr_img, hr_img = create_hr_lr_pair(img, scaling_factor)

    return lr_img, hr_img

# %%
def create_hr_lr_pair(img, scaling_factor=2):
    height, width = img.shape[0:2]

    # Take the largest possible center-crop of it such that its dimensions are perfectly divisible by the scaling factor
    x_remainder = width % (scaling_factor)
    y_remainder = height % (scaling_factor)
    left = x_remainder // 2
    top = y_remainder // 2
    right = left + (width - x_remainder)
    bottom = top + (height - y_remainder)
    hr_img = img[top:bottom, left:right]

    hr_height, hr_width = hr_img.shape[0:2]

    hr_img = np.array(hr_img, dtype='float32')
    lr_img = imresize(hr_img, 1. / scaling_factor)  # equivalent to matlab's imresize
    flag=0
    lr_img = np.uint8(np.clip(lr_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    hr_img = np.uint8(hr_img)
    lr_height, lr_width = lr_img.shape[0:2]

    # Sanity check
    assert hr_width == lr_width * scaling_factor and hr_height == lr_height * scaling_factor
    lr_img = convert_image(lr_img, source='array', target='[0, 1]')
    hr_img = convert_image(hr_img, source='array', target='[0, 1]')

    return lr_img, hr_img

# %%
def convert_image(img, source, target):
    if source == 'array':
        img = torch.from_numpy(img.transpose((2, 0, 1))).contiguous()#chw
        img = img.to(dtype=torch.float32).div(255)
    elif source == '[0, 1]':
        img = torch.clamp(img, 0, 1)  # useful to post-process output of models that can overspill
    
    if target == '[0, 1]':
        pass  # already in [0, 1]
    elif target == 'y-channel':
        img = torch.matmul(img.permute(0, 2, 3, 1), RGB_WEIGHTS.to(img.device)) + 16.
    
    return img

# %%
def post_process(img):
    img = img.detach().cpu().numpy()
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %%
def load_dataset(test_images_dir, scaling_factor=2):
    # Input images for the model
    INPUTS_LR = []

    # Post-processed images for visualization
    IMAGES_LR = []
    IMAGES_HR = []
    
    # Load the test images
    count=0
    img_paths =  glob.glob(os.path.join(test_images_dir, '*'))
    img_paths = sorted(img_paths)
    for img_path in img_paths:
        img = cv2.resize(cv2.imread(img_path),[512,512],interpolation=cv2.INTER_CUBIC)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        lr_img, hr_img = preprocess(img, scaling_factor)#chw
        INPUTS_LR.append(lr_img)#chw
        IMAGES_LR.append(post_process(lr_img))#hwc
        IMAGES_HR.append(post_process(hr_img))#hwc

    return INPUTS_LR, IMAGES_LR, IMAGES_HR

# %%
test_images_dir = "input/Set14"
INPUTS_LR, IMAGES_LR, IMAGES_HR = load_dataset(test_images_dir, scaling_factor=4)
for i, img_lr in enumerate(INPUTS_LR):
    img_lr = img_lr.cpu().detach().numpy()
    img_lr = img_lr.astype(np.float32)
    fid = open("input/raw/img"+str(i)+ ".raw", 'wb')
    img_lr.tofile(fid)
    fid.close()

# %%
import matplotlib.pyplot as plt
plt.imshow(IMAGES_LR[0])
plt.imshow(IMAGES_HR[0])

# %%
with open("input/input.txt", "w") as f:
    for i in range(14):
        file_path = f"./raw/img{i}.raw"
        f.write(file_path + "\n")

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network models/srgan.onnx --output_path ${MODEL_PATH}.cpp
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${MODEL_PATH}.cpp -b ${MODEL_PATH}.bin -o models/model_libs
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs/x86_64-linux-clang/lib${MODEL_NAME}.so \
#               --binary_file ${MODEL_NAME}.serialized
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# 2024-04-03 13:33:23,095 - 235 - INFO - Simplified model validation is successful
# 2024-04-03 13:33:24,187 - 235 - INFO - Saving QNN Model...
# 2024-04-03 13:33:24,209 - 235 - INFO - Skipping quantization, no input_list provided
# 2024-04-03 13:33:24,218 - 235 - INFO - Model CPP saved at: models/srgan_fp32.cpp
# 2024-04-03 13:33:24,218 - 235 - INFO - Model BIN saved at: /local/mnt/workspace/gokul/qnn-fin/1/models/SRGAN/models/srgan_fp32.bin
# 2024-04-03 13:33:24,219 - 235 - INFO - Conversion complete!
# INFO: Creating Output dir /local/mnt/workspace/gokul/qnn-fin/1/models/SRGAN/models/model_libs.
#
# --------------------------
# INFO: Building for target: x86_64-linux-clang
# --------------------------
# mkdir -p obj/x86_64-linux-clang
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModel.cpp -o obj/x86_64-linux-clang/QnnModel.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModelPal.cpp -o obj/x86_64-linux-clang/QnnModelPal.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnWrapperUtils.cpp -o obj/x86_64-linux-clang/QnnWrapperUtils.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/srgan_fp32.cpp -o obj/x86_64-linux-clang/srgan_fp32.o
# mkdir -p obj/binary/x86_64-linux-clang
# touch obj/binary/extractbinary
# mkdir -p libs/x86_64-linux-clang
#
# --------------------------
# INFO: Building for target: aarch64-android
# --------------------------
# Android NDK: android-16 is unsupported. Using minimum supported version android-19.
# Android NDK: WARNING: Unsupported source file extensions in jni/Android.mk for module srgan_fp32
# Android NDK:   /conv_first_bias.o /conv_first_weight.o /conv_last_bias.o /conv_last_weight.o /HRconv_bias.o /HRconv_weight.o /_lrelu_1_LeakyRelu_coeff.o /_lrelu_2_LeakyRelu_coeff.o /_lrelu_3_LeakyRelu_coeff.o /_lrelu_LeakyRelu_coeff.o /recon_trunk_0_conv1_bias.o /recon_trunk_0_conv1_weight.o /recon_trunk_0_conv2_b
# 2024-04-03 13:35:39,684 - 235 - INFO - Model BIN saved at: /local/mnt/workspace/gokul/qnn-fin/1/models/SRGAN/models/srgan_w8a8.bin
# 2024-04-03 13:35:39,685 - 235 - INFO - Conversion complete!
#      0.5ms [  INFO ] Inferences will run in sync mode
#      0.6ms [  INFO ] Initializing logging in the backend. Callback: [0x7fbef523ee10], Log Level: [3]
#      0.6ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.8ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      1.0ms [  INFO ] Entering QuantizeRuntimeApp flow
#      4.8ms [  INFO ] CpuGraph::finalize
#    198.0ms [  INFO ] CpuGraph::execute
#   1676.2ms [  INFO ] cleaning up resources for input tensors
#   1676.2ms [  INFO ] cleaning up resources for output tensors
#   1680.3ms [  INFO ] CpuGraph::execute
#   2768.7ms [  INFO ] cleaning up resources for input tensors
#   2768.7ms [  INFO ] cleaning up resources for output tensors
#   2771.4ms [  INFO ] CpuGraph::execute
#   4025.3ms [  INFO ] cleaning up resources for input tensors
#   4025.3ms [  INFO ] cleaning up resources for output tensors
#   4028.0ms [  INFO ] CpuGraph::execute
#   5103.8ms [  INFO ] cleaning up resources for input tensors
#   5103.8ms [  INFO ] cleaning up resources for output tensors
#   5106.5ms [  INFO ] CpuGraph::execute
#   6188.6ms [  INFO ] cleaning up resources for input tensors
#   6188.6ms [  INFO ] cleaning up resources for output tensors
#   6191.2ms [  INFO ] CpuGraph::execute
#   7395.7ms [  INFO ] cleaning up resources for input tensors
#   7395.7ms [  INFO ] cleaning up resources for output tensors
#   7398.4ms [  INFO ] CpuGraph::execute
#   8458.0ms [  INFO ] cleaning up resources for input tensors
#   8458.1ms [  INFO ] cleaning up resources for output tensors
#   8460.8ms [  INFO ] CpuGraph::execute
#   9571.3ms [  INFO ] cleaning up resources for input tensors
#   9571.3ms [  INFO ] cleaning up resources for output tensors
#   9573.9ms [  INFO ] CpuGraph::execute
#  10654.8ms [  INFO ] cleaning up resources for input tensors
#  10654.8ms [  INFO ] cleaning up resources for output tensors
#  10657.7ms [  INFO ] CpuGraph::execute
#  11758.9ms [  INFO ] cleaning up resources for input tensors
#  11758.9ms [  INFO ] cleaning up resources for output tensors
#  11761.4ms [  INFO ] CpuGraph::execute
#  13048.1ms [  INFO ] cleaning up resources for input tensors
#  13048.1ms [  INFO ] cleaning up resources for output tensors
#  13050.8ms [  INFO ] CpuGraph::execute
#  14128.2ms [  INFO ] cleaning up resources for input tensors
#  14128.3ms [  INFO ] cleaning up resources for output tensors
#  14130.9ms [  INFO ] CpuGraph::execute
#  15209.6ms [  INFO ] cleaning up resources for input tensors
#  15209.6ms [  INFO ] cleaning up resources for output tensors
#  15212.3ms [  INFO ] CpuGraph::execute
#  16341.2ms [  INFO ] cleaning up resources for input tensors
#  16341.2ms [  INFO ] cleaning up resources for output tensors
#  16398.1ms [  INFO ] Freeing graphsInfo

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${QUANTIZED_MODEL_PATH}.cpp -b ${QUANTIZED_MODEL_PATH}.bin -o models/model_libs2
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# INFO: Creating Output dir /local/mnt/workspace/gokul/qnn-fin/1/models/SRGAN/models/model_libs2.
#
# --------------------------
# INFO: Building for target: x86_64-linux-clang
# --------------------------
# mkdir -p obj/x86_64-linux-clang
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModel.cpp -o obj/x86_64-linux-clang/QnnModel.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModelPal.cpp -o obj/x86_64-linux-clang/QnnModelPal.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnWrapperUtils.cpp -o obj/x86_64-linux-clang/QnnWrapperUtils.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/srgan_w8a8.cpp -o obj/x86_64-linux-clang/srgan_w8a8.o
# mkdir -p obj/binary/x86_64-linux-clang
# touch obj/binary/extractbinary
# mkdir -p libs/x86_64-linux-clang
#
# --------------------------
# INFO: Building for target: aarch64-android
# --------------------------
# Android NDK: android-16 is unsupported. Using minimum supported version android-19.
# Android NDK: WARNING: Unsupported source file extensions in jni/Android.mk for module srgan_w8a8
# Android NDK:   /conv_first_bias.o /conv_first_weight.o /conv_last_bias.o /conv_last_weight.o /HRconv_bias.o /HRconv_weight.o /_lrelu_1_LeakyRelu_coeff.o /_lrelu_2_LeakyRelu_coeff.o /_lrelu_3_LeakyRelu_coeff.o /_lrelu_LeakyRelu_coeff.o /recon_trunk_0_conv1_bias.o /recon_trunk_0_conv1_weight.o /recon_trunk_0_conv2_bias.o /recon_trunk_0_conv2_weight.o /recon_trunk_10_conv1_bias.o /recon_trunk_10_conv1_weight.o /recon_trunk_10_conv2_bias.o /recon_trunk_10_conv2_weight.o /recon_trunk_11_conv1_bias.o /recon_trunk_11_conv1_weight.o /recon_trunk_11_conv2_bias.o /recon_trunk_11_conv2_weight.o /recon_trunk_12_conv1_bias.o /recon_trunk_12_conv1_weight.o /recon_trunk_12_conv2_bias.o /recon_trunk_12_conv2_weight.o /recon_trunk_13_conv1_bias.o /recon_trunk_13_conv1_weight.o /recon_trunk_13_conv2_bias.o /recon_trunk_13_conv2_weight.o /recon_trunk_14_conv1_bias.o /recon_trunk_14_conv1_weight.o /recon_trunk_14_conv2_bias.o /recon_trunk_14_conv2_weight.o /recon_trunk_15_conv1_bias.o /recon_trunk_15_conv1_weight.o /recon_trunk_15_conv2_bias.o /recon_trunk_15_conv2_weight.o /recon_trunk_1_conv1_bias.o /recon_trunk_1_conv1_weight.o /recon_trunk_1_conv2_bias.o /recon_trunk_1_conv2_weight.o /recon_trunk_2_conv1_bias.o /recon_trunk_2_conv1_weight.o /recon_trunk_2_conv2_bias.o /recon_trunk_2_conv2_weight.o /recon_trunk_3_conv1_bias.o /recon_trunk_3_conv1_weight.o /recon_trunk_3_conv2_bias.o /recon_trunk_3_conv2_weight.o /recon_trunk_4_conv1_bias.o /recon_trunk_4_conv1
13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:809:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__recon_trunk_recon_trunk_1_conv2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:796:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
# ...
#             {.clientBuf= { .data=(uint8_t*)__recon_trunk_recon_trunk_10_conv1_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3490:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3491:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3487:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3489:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3510:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3521:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__recon_trunk_recon_trunk_10_conv1_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3508:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3509:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3505:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3507:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3528:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3539:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__recon_trunk_recon_trunk_10_conv1_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3526:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3527:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3523:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3525:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3541:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3543:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3555:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3566:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3553:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3554:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3586:39: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                       .id=0,
#                                       ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3597:39: note: first non-designated initializer is here
#                                       {.clientBuf= { .data=BINVARSTART(recon_trunk_10_conv2_weight),
#                                       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3584:37: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                     .version= QNN_TENSOR_VERSION_1,
#                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3585:37: note: first non-designated initializer is here
#                                     {.v1= {
#                                     ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3605:39: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                       .id=0,
#                                       ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3616:39: note: first non-designated initializer is here
#                                       {.clientBuf= { .data=BINVARSTART(recon_trunk_10_conv2_bias),
#                                       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3603:37: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                     .version= QNN_TENSOR_VERSION_1,
#                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3604:37: note: first non-designated initializer is here
#                                     {.v1= {
#                                     ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3633:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3644:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__recon_trunk_recon_trunk_10_conv2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3631:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3632:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3628:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3630:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3651:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3662:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__recon_trunk_recon_trunk_10_conv2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3649:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3650:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3646:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3648:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3669:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3680:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__recon_trunk_recon_trunk_10_conv2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3667:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3668:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3664:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3666:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3682:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3684:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3696:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3707:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3694:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3695:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3733:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/srgan_w8a8.cpp:3744:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3731:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/srgan_w8a8.cpp:3732:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/srgan_w8a8.cpp:3764:39: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                       .id=0,
#                                       ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3775:39: note: first non-designated initializer is here
#                                       {.clientBuf= { .data=BINVARSTART(recon_trunk_11_conv1_weight),
#                                       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3762:37: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                     .version= QNN_TENSOR_VERSION_1,
#                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3763:37: note: first non-designated initializer is here
#                                     {.v1= {
#                                     ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3783:39: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                       .id=0,
#                                       ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/srgan_w8a8.cpp:3794:39: note: first non-designated initializer is here
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs2/x86_64-linux-clang/lib${QUANTIZED_MODEL_NAME}.so \
#               --binary_file ${QUANTIZED_MODEL_NAME}.serialized \
#               --config_file htp_vtcm_config.json
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# qnn-context-binary-generator pid:2676463

# %% [markdown]
# # Post-process model output

# %%
def post_process_sr(img):
#     img = img.detach().cpu().numpy()
    img = np.fromfile(img, np.float32)
    img = img.reshape((3,512, 512)).astype(np.float32)
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %% [markdown]
# Method to calcualte PSNR

# %%
def compute_psnr(img_pred, img_true, data_range=255., eps=1e-8):
    """
    Compute PSNR between super-resolved and original images.
    
    :param img_pred:
        The super-resolved image obtained from the model
    :param img_true:
        The original high-res image
    :param data_range:
        Default = 255
    :param eps:
        Default = 1e-8
    :return:
        PSNR value
    """
    err = (img_pred - img_true) ** 2
    err = err.mean(dim=-1).mean(dim=-1)

    return 10. * torch.log10((data_range ** 2) / (err + eps))

# %%
def evaluate_psnr(y_pred, y_true):
    """
    Evaluate individual PSNR metric for each super-res and actual high-res image-pair.
    
    :param y_pred:
        The super-resolved image from the model
    :param y_true:
        The original high-res image
    :return:
        The evaluated PSNR metric for the image-pair
    """
    y_pred = y_pred.transpose(2, 0, 1)[None] / 255.
    y_true = y_true.transpose(2, 0, 1)[None] / 255.

    sr_img = convert_image(torch.FloatTensor(y_pred),
                           source='[0, 1]',
                           target='y-channel')
    hr_img = convert_image(torch.FloatTensor(y_true),
                           source='[0, 1]',
                           target='y-channel')

    return compute_psnr(sr_img, hr_img)

# %%
def evaluate_average_psnr(sr_images, hr_images):
    """
    Evaluate the avg PSNR metric for all test-set super-res and high-res images.

    :param sr_images:
        The list of super-resolved images obtained from the model for the given test-images
    :param hr_images:
        The list of original high-res test-images
    :return:
        Average PSNR metric for all super-resolved and high-res test-set image-pairs
    """
    psnr = []
    for sr_img, hr_img in zip(sr_images, hr_images):
        psnr.append(evaluate_psnr(sr_img, hr_img))
        print(evaluate_psnr(sr_img, hr_img))

 

    # Convert the list of tensor values to a tensor array
    psnr_tensor = torch.cat(psnr)

 

    # Calculate the mean of the tensor array
    average_psnr = torch.mean(psnr_tensor)

    return average_psnr

# %% [markdown]
# # Creating Bin and Lib Folder on Device

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/bin" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/lib" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/dsp/lib"

# %% [markdown]
# # Pushing all Lib and Bin files onto Device

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/$ONDEVICE_FOLDER"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/$QNN_TARGET_STL /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/bin/$QNN_TARGET_ARCH/qnn-net-run /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/hexagon-v73/unsigned/*.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/*.so /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtp.so: 1 file pushed, 0 skipped. 329.8 MB/s (1545520 bytes in 0.004s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/bin/aarch64-android/qnn-net-run: 1 file pushed, 0 skipped. 360.4 MB/s (1441208 bytes in 0.004s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libCalculator_skel.so: 1 file pushed, 0 skipped. 39.7 MB/s (7128 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73QemuDriver.so: 1 file pushed, 0 skipped. 431.0 MB/s (7601584 bytes in 0.017s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73Skel.so: 1 file pushed, 0 skipped. 453.7 MB/s (7360784 bytes in 0.015s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73.so: 1 file pushed, 0 skipped. 455.4 MB/s (8025008 bytes in 0.017s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSaver.so: 1 file pushed, 0 skipped. 317.8 MB/s (280044 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSystem.so: 1 file pushed, 0 skipped. 218.5 MB/s (56360 bytes in 0.000s)
# 6 files pushed, 0 skipped. 223.6 MB/s (23330908 bytes in 0.099s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libhta_hexagon_runtime_qnn.so: 1 file pushed, 0 skipped. 375.2 MB/s (2789832 bytes in 0.007s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnChrometraceProfilingReader.so: 1 file pushed, 0 skipped. 352.3 MB/s (516568 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnCpu.so: 1 file pushed, 0 skipped. 450.2 MB/s (4822376 bytes in 0.010s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspNetRunExtensions.so: 1 file pushed, 0 skipped. 406.1 MB/s (634024 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDsp.so: 1 file pushed, 0 skipped. 388.9 MB/s (1238520 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66CalculatorStub.so: 1 file pushed, 0 skipped. 55.8 MB/s (6368 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66Stub.so: 1 file pushed, 0 skipped. 349.4 MB/s (278216 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuNetRunExtensions.so: 1 file pushed, 0 skipped. 393.1 MB/s (626472 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuProfilingReader.so: 1 file pushed, 0 skipped. 385.9 MB/s (517864 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpu.so: 1 file pushed, 0 skipped. 452.0 MB/s (4484984 bytes in 0.009s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtaNetRunExtensions.so: 1 file pushed, 0 skipped. 414.9 MB/s (621800 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHta.so: 1 file pushed, 0 skipped. 369.4 MB/s (896360 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpNetRunExtensions.so: 1 file pushed, 0 skipped. 405.1 MB/s (721360 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpOptraceProfilingReader.so: 1 file pushed, 0 skipped. 371.6 MB/s (617896 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpPrepare.so: 1 file pushed, 0 skipped. 483.9 MB/s (26627504 bytes in 0.052s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpProfilingReader.so: 1 file pushed, 0 skipped. 390.3 MB/s (502584 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtp.so: 1 file pushed, 0 skipped. 446.8 MB/s (1545520 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV68CalculatorStub.so: 1 file pushed, 0 skipped. 51.1 MB/s (6416 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV68Stub.so: 1 file pushed, 0 skipped. 345.4 MB/s (281936 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV69CalculatorStub.so: 1 file pushed, 0 skipped. 62.6 MB/s (6416 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV69Stub.so: 1 file pushed, 0 skipped. 316.3 MB/s (282816 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV73CalculatorStub.so: 1 file pushed, 0 skipped. 58.9 MB/s (6968 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV73Stub.so: 1 file pushed, 0 skipped. 336.9 MB/s (290408 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV75CalculatorStub.so: 1 file pushed, 0 skipped. 62.1 MB/s (6968 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV75Stub.so: 1 file pushed, 0 skipped. 361.2 MB/s (290408 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnJsonProfilingReader.so: 1 file pushed, 0 skipped. 380.2 MB/s (521504 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnModelDlc.so: 1 file pushed, 0 skipped. 413.7 MB/s (1598240 bytes in 0.004s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSaver.so: 1 file pushed, 0 skipped. 395.3 MB/s (689360 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSystem.so: 1 file pushed, 0 skipped. 325.9 MB/s (229024 bytes in 0.001s)
# 29 files pushed, 0 skipped. 309.7 MB/s (51658712 bytes in 0.159s)

# %% [markdown]
# # Pushing Artifacts on to Device

# %%
# %%bash
# #find ./raw -name *.raw > list.txt
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push output/${QUANTIZED_MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push output/${MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push models/model_libs2/aarch64-android/lib${QUANTIZED_MODEL_NAME}.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $RAW_FILE_FOLDER /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $TARGET_INPUT_LIST /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# output/srgan_w8a8.serialized.bin: 1 file pushed, 0 skipped. 648.5 MB/s (1868064 bytes in 0.003s)
# adb: error: cannot stat 'output/srgan_fp32.serialized.bin': No such file or directory
# models/model_libs2/aarch64-android/libsrgan_w8a8.so: 1 file pushed, 0 skipped. 635.1 MB/s (1989360 bytes in 0.003s)
# input/raw/: 14 files pushed, 0 skipped. 47.5 MB/s (2752512 bytes in 0.055s)
# input/input.txt: 1 file pushed, 0 skipped. 4.9 MB/s (214 bytes in 0.000s)

# %% [markdown]
# # Inferencing 8 bit DLC on DSP Runtime
# Give name of DLC in OUTPUT_DLC_QUANTIZED8 and ondevice folder

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="srgan"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="srgan_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_Quant_DSP
# cd /data/local/tmp/$ONDEVICE_FOLDER  && 
# ./qnn-net-run --backend libQnnHtp.so --input_list input.txt --retrieve_context ${QUANTIZED_MODEL_NAME}.serialized.bin --output_dir $OUTPUT_FOLDER

# %% [markdown]
# # Inferencing 32b DLC on CPU Runtime
# Give name of DLC in OUTPUT_DLC_32 and ondevice folder

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="srgan"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="srgan_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_CPU
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnCpu.so --input_list input.txt --model lib${QUANTIZED_MODEL_NAME}.so --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:6398

# %% [markdown]
# # Pulling Output folder generated on different precision and cores

# %%
# %%bash
# # rm -rf OUTPUT_Quant_DSP
# rm -rf OUTPUT_CPU

# %%
# %%bash
#
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# # $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_Quant_DSP output/OUTPUT_Quant_DSP
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_CPU output/OUTPUT_CPU
# Out:
# /data/local/tmp/srgan/OUTPUT_CPU/: 14 files pulled, 0 skipped. 50.6 MB/s (44040192 bytes in 0.830s)

# %% [markdown]
# # Calculate PSNR
# * Pass path of two raw image in Argument.

# %%
val = []
for i in range(10):
    val.append(IMAGES_HR[i])
val[0].shape
# Out:
# (512, 512, 3)

# %%
folder = ["output/OUTPUT_CPU"]
RGB_WEIGHTS = torch.FloatTensor([65.481, 128.553, 24.966])
for j in range(0,len(folder)):
    IMAGES_SR = []
    for i in range(0,13):
        IMAGES_SR.append(post_process_sr(folder[j]+"/Result_"+str(i)+"/_155.raw"))
    print(folder[j]," (Average PSNR) :: ",evaluate_average_psnr(IMAGES_SR, IMAGES_HR))
    print("\n============================\n")
# Out:
# tensor([17.7309])
# tensor([18.2507])
# tensor([16.9855])
# tensor([19.6390])
# tensor([15.4548])
# tensor([23.7786])
# tensor([17.4787])
# tensor([20.5850])
# tensor([20.1815])
# tensor([17.6208])
# tensor([17.0461])
# tensor([19.6377])
# tensor([15.3087])
# output/OUTPUT_CPU  (Average PSNR) ::  tensor(18.4383)
#
# ============================

# %%
import matplotlib.pyplot as plt
plt.imshow(IMAGES_SR[5])

# %%
plt.imshow(IMAGES_HR[5])
