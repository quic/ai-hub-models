# %% [markdown]
# # Setting Up All Artifacts details

# %%
import os
os.environ['QNN_SDK_ROOT']="/local/mnt/workspace/gokul/QNN/2.19.0.240124" #set up your qnn path here.
os.environ['ANDROID_NDK_ROOT']="/local/mnt/workspace/gokul/android-ndk-r25c"
os.environ['RAW_FILE_FOLDER']="input/raw"
os.environ['MODEL_NAME']="xlsr_fp32"
os.environ['QUANTIZED_MODEL_NAME']="xlsr_w8a8"
os.environ['MODEL_PATH']="models/xlsr_fp32"
os.environ['QUANTIZED_MODEL_PATH']="models/xlsr_w8a8"
os.environ['TARGET_INPUT_LIST']="input/input.txt"
os.environ['ONDEVICE_FOLDER']="xlsr"
os.environ['DEVICE_HOST']="localhost"
os.environ['DEVICE_ID']="bc468c1d" #fill your device-id. Use command "adb devices" to get devices names. example :"e18d5d0"
os.environ['QNN_TARGET_ARCH']="aarch64-android"
os.environ['QNN_TARGET_STL']="libQnnHtp.so"

# %%
import cv2
import glob
import os
import numpy as np
import torch

# %%
os.makedirs('utils', exist_ok = True)

# %%
# %%bash
# git clone https://github.com/quic/aimet-model-zoo/
# Out:
# Cloning into 'aimet-model-zoo'...

# %%
# %%bash
# cp -r xlsr.patch aimet-model-zoo
# cd aimet-model-zoo
# git apply xlsr.patch

# %%
# %%bash
# cp -r aimet-model-zoo/aimet_zoo_torch/common/super_resolution/ utils/
# cp -r aimet-model-zoo/aimet_zoo_torch/common/downloader.py utils/super_resolution/
# cp -r aimet-model-zoo/aimet_zoo_torch/xlsr/model/ utils/
# rm -rf aimet-model-zoo/

# %%
# %%bash
# cd utils
# touch __init__.py

# %%
from utils.model.model_definition import XLSR
from utils.super_resolution.imresize import imresize

# %%
model_fp32 = XLSR("xlsr_4x_w8a8",scaling_factor=4)
model_fp32.from_pretrained(quantized=False)

# %%
os.makedirs('models', exist_ok= True)
os.makedirs('output', exist_ok= True)

# %%
import os
dummy_input = torch.randn(1,3, 128, 128).type(torch.FloatTensor).to('cpu')
torch.onnx.export(model_fp32, dummy_input, "./models/xlsr.onnx",opset_version=11)

# %% [markdown]
# # Download dataset
# <ul>
#     <li>  Dataset link wget https://figshare.com/ndownloader/files/38256855  </li>
# <li>Below block will automatically download datsest, but in case if it fails please download from above link.</li>
#     <li> Recommended, to comment below code, if already downloaded dataset once.</li>
#     <ul>

# %%
# %%bash
# wget https://figshare.com/ndownloader/files/38256855
# unzip 38256855 -d input
# rm -rf 38256855
# rm -rf input/Set14/image_SRF_4
# rm -rf input/Set14/image_SRF_3
# mkdir input/raw
# find input/Set14/image_SRF_2 -name '*_LR*' -delete
# mv input/Set14/image_SRF_2/* input/Set14/
# rm -rf input/Set14/image_SRF_2/
# Out:
# --2024-03-04 10:13:38--  https://figshare.com/ndownloader/files/38256855
# Resolving figshare.com (figshare.com)... 2a05:d018:1f4:d003:8d1a:b96f:3b54:baed, 2a05:d018:1f4:d000:bbd2:6aa9:5ad6:a6d4, 34.249.22.33, ...
# Connecting to figshare.com (figshare.com)|2a05:d018:1f4:d003:8d1a:b96f:3b54:baed|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files
# ## Preprocess dataset

# %%
RGB_WEIGHTS = torch.FloatTensor([65.481, 128.553, 24.966])
def preprocess(img, scaling_factor=2):
    lr_img, hr_img = create_hr_lr_pair(img, scaling_factor)

    return lr_img, hr_img

# %%
def create_hr_lr_pair(img, scaling_factor=2):
    height, width = img.shape[0:2]

    # Take the largest possible center-crop of it such that its dimensions are perfectly divisible by the scaling factor
    x_remainder = width % (scaling_factor)
    y_remainder = height % (scaling_factor)
    left = x_remainder // 2
    top = y_remainder // 2
    right = left + (width - x_remainder)
    bottom = top + (height - y_remainder)
    hr_img = img[top:bottom, left:right]

    hr_height, hr_width = hr_img.shape[0:2]

    hr_img = np.array(hr_img, dtype='float32')
    lr_img = imresize(hr_img, 1. / scaling_factor)  # equivalent to matlab's imresize
    flag=0
    lr_img = np.uint8(np.clip(lr_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    hr_img = np.uint8(hr_img)
    lr_height, lr_width = lr_img.shape[0:2]

    # Sanity check
    assert hr_width == lr_width * scaling_factor and hr_height == lr_height * scaling_factor
    lr_img = convert_image(lr_img, source='array', target='[0, 1]')
    hr_img = convert_image(hr_img, source='array', target='[0, 1]')

    return lr_img, hr_img

# %%
def convert_image(img, source, target):
    if source == 'array':
        img = torch.from_numpy(img.transpose((2, 0, 1))).contiguous()#chw
        img = img.to(dtype=torch.float32).div(255)
    elif source == '[0, 1]':
        img = torch.clamp(img, 0, 1)  # useful to post-process output of models that can overspill
    
    if target == '[0, 1]':
        pass  # already in [0, 1]
    elif target == 'y-channel':
        img = torch.matmul(img.permute(0, 2, 3, 1), RGB_WEIGHTS.to(img.device)) + 16.
    
    return img

# %%
def post_process(img):
    img = img.detach().cpu().numpy()
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %%
def load_dataset(test_images_dir, scaling_factor=2):
    # Input images for the model
    INPUTS_LR = []

    # Post-processed images for visualization
    IMAGES_LR = []
    IMAGES_HR = []
    
    # Load the test images
    count=0
    img_paths =  glob.glob(os.path.join(test_images_dir, '*'))
    img_paths = sorted(img_paths)
    for img_path in img_paths:
        img = cv2.resize(cv2.imread(img_path),[512,512],interpolation=cv2.INTER_CUBIC)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        lr_img, hr_img = preprocess(img, scaling_factor)#chw
        INPUTS_LR.append(lr_img)#chw
        IMAGES_LR.append(post_process(lr_img))#hwc
        IMAGES_HR.append(post_process(hr_img))#hwc

    return INPUTS_LR, IMAGES_LR, IMAGES_HR

# %%
test_images_dir = "input/Set14"
INPUTS_LR, IMAGES_LR, IMAGES_HR = load_dataset(test_images_dir, scaling_factor=4)
for i, img_lr in enumerate(INPUTS_LR):
    img_lr = img_lr.cpu().detach().numpy()
    img_lr = img_lr.astype(np.float32)
    fid = open("input/raw/img"+str(i)+ ".raw", 'wb')
    img_lr.tofile(fid)
    fid.close()

# %%
INPUTS_LR[0].shape
# Out:
# torch.Size([3, 128, 128])

# %%
with open("input/input.txt", "w") as f:
    for i in range(14):
        file_path = f"./raw/img{i}.raw"
        f.write(file_path + "\n")

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network models/xlsr.onnx --output_path ${MODEL_PATH}.cpp
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${MODEL_PATH}.cpp -b ${MODEL_PATH}.bin -o models/model_libs
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs/x86_64-linux-clang/lib${MODEL_NAME}.so \
#               --binary_file ${MODEL_NAME}.serialized

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# cd input
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network ../models/xlsr.onnx --output_path ../${QUANTIZED_MODEL_PATH}.cpp --input_list input.txt \
#                 --param_quantizer "adjusted" --act_quantizer "enhanced"
# cd ..
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${QUANTIZED_MODEL_PATH}.cpp -b ${QUANTIZED_MODEL_PATH}.bin -o models/model_libs2
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs2/x86_64-linux-clang/lib${QUANTIZED_MODEL_NAME}.so \
#               --binary_file ${QUANTIZED_MODEL_NAME}.serialized
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# 2024-03-04 10:13:45,830 - 235 - INFO - Simplified model validation is successful
# 2024-03-04 10:13:46,691 - 235 - INFO - Saving QNN Model...
# IrQuantizer: Quantizer param type: adjusted will be deprecated in future releases
# IrQuantizer: Quantizer type: adjusted is no longer supported. Using TF quantizer instead
# 2024-03-04 10:13:48,991 - 235 - INFO - Model CPP saved at: ../models/xlsr_w8a8.cpp
# 2024-03-04 10:13:48,991 - 235 - INFO - Model BIN saved at: /local/mnt/workspace/gokul/models-for-solutions/01-super-resolution/xlsr/models/xlsr_w8a8.bin
# 2024-03-04 10:13:48,991 - 235 - INFO - Conversion complete!
#      0.1ms [  INFO ] Inferences will run in sync mode
#      0.1ms [  INFO ] Initializing logging in the backend. Callback: [0x7f70a5842e10], Log Level: [3]
#      0.1ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.2ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.2ms [  INFO ] Entering QuantizeRuntimeApp flow
#      0.9ms [  INFO ] CpuGraph::finalize
#     12.3ms [  INFO ] CpuGraph::execute
#    238.8ms [  INFO ] cleaning up resources for input tensors
#    238.8ms [  INFO ] cleaning up resources for output tensors
#    245.3ms [  INFO ] CpuGraph::execute
#    409.5ms [  INFO ] cleaning up resources for input tensors
#    409.5ms [  INFO ] cleaning up resources for output tensors
#    413.1ms [  INFO ] CpuGraph::execute
#    585.1ms [  INFO ] cleaning up resources for input tensors
#    585.1ms [  INFO ] cleaning up resources for output tensors
#    589.0ms [  INFO ] CpuGraph::execute
#    763.2ms [  INFO ] cleaning up resources for input tensors
#    763.2ms [  INFO ] cleaning up resources for output tensors
#    766.7ms [  INFO ] CpuGraph::execute
#    895.9ms [  INFO ] cleaning up resources for input tensors
#    895.9ms [  INFO ] cleaning up resources for output tensors
#    899.6ms [  INFO ] CpuGraph::execute
#   1048.4ms [  INFO ] cleaning up resources for input tensors
#   1048.4ms [  INFO ] cleaning up resources for output tensors
#   1051.8ms [  INFO ] CpuGraph::execute
#   1208.1ms [  INFO ] cleaning up resources for input tensors
#   1208.1ms [  INFO ] cleaning up resources for output tensors
#   1212.0ms [  INFO ] CpuGraph::execute
#   1359.0ms [  INFO ] cleaning up resources for input tensors
#   1359.0ms [  INFO ] cleaning up resources for output tensors
#   1362.5ms [  INFO ] CpuGraph::execute
#   1533.9ms [  INFO ] cleaning up resources for input tensors
#   1533.9ms [  INFO ] cleaning up resources for output tensors
#   1537.3ms [  INFO ] CpuGraph::execute
#   1659.5ms [  INFO ] cleaning up resources for input tensors
#   1659.5ms [  INFO ] cleaning up resources for output tensors
#   1663.0ms [  INFO ] CpuGraph::execute
#   1848.2ms [  INFO ] cleaning up resources for input tensors
#   1848.2ms [  INFO ] cleaning up resources for output tensors
#   1852.0ms [  INFO ] CpuGraph::execute
#   1972.2ms [  INFO ] cleaning up resources for input tensors
#   1972.2ms [  INFO ] cleaning up resources for output tensors
#   1975.7ms [  INFO ] CpuGraph::execute
#   2125.1ms [  INFO ] cleaning up resources for input tensors
#   2125.1ms [  INFO ] cleaning up resources for output tensors
#   2129.4ms [  INFO ] CpuGraph::execute
#   2274.3ms [  INFO ] cleaning up resources for input tensors
#   2274.3ms [  INFO ] cleaning up resources for output tensors
#   2290.2ms [  INFO ] Freeing graphsInfo
#
# --------------------------
# INFO: Building for target: x86_64-linux-clang
# --------------------------
# mkdir -p obj/x86_64-linux-clang
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModel.cpp -o obj/x86_64-linux-clang/QnnModel.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModelPal.cpp -o obj/x86_64-linux-clang/QnnModelPal.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnWrapperUtils.cpp -o obj/x86_64-linux-clang/QnnWrapperUtils.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/xlsr_w8a8.cpp -o obj/x86_64-linux-clang/xlsr_w8a8.o
# mkdir -p obj/binary/x86_64-linux-clang
# touch obj/binary/extractbinary
# mkdir -p libs/x86_64-linux-clang
#
# --------------------------
# INFO: Building for target: aarch64-android
# --------------------------
# Android NDK: android-16 is unsupported. Using minimum supported version android-19.
# Android NDK: WARNING: Unsupported source file extensions in jni/Android.mk for module xlsr_w8a8
# Android NDK:   /cnn_0_bias.o /cnn_0_weight.o /cnn_2_bias.o /cnn_2_weight.o /cnn_3_net_0_bias.o /cnn_3_net_0_weight.o /cnn_3_net_2_bias.o /cnn_3_net_2_weight.o /cnn_4_net_0_bias.o /cnn_4_net_0_weight.o /cnn_4_net_2_bias.o /cnn_4_net_2_weight.o /cnn_5_net_0_bias.o /cnn_5_net_0_weight.o /cnn_5_net_2_bias.o /cnn_5_net_2_weight.o /residual_bias.o /residual_weight.o /tail_0_bias.o /tail_0_weight.o /tail_2_bias.o /tail_2_weight.o
# [arm64-v8a] Compile++      : xlsr_w8a8 <= QnnModel.cpp
# [arm64-v8a] Compile++      : xlsr_w8a8 <= QnnModelPal.cpp
# [arm64-v8a] Compile++      : xlsr_w8a8 <= QnnWrapperUtils.cpp
# [arm64-v8a] Compile++      : xlsr_w8a8 <= xlsr_w8a8.cpp
# jni/xlsr_w8a8.cpp:39:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:50:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=nullptr,
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:37:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:38:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:58:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:69:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(residual_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:56:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:57:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:77:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:88:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(residual_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:75:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:76:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:105:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:116:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__residual_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:103:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:104:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:100:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:102:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:123:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:134:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__residual_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:121:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:122:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:118:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:120:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:141:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:152:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__residual_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:139:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:140:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:136:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:138:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:154:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:156:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:168:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:179:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:166:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:167:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:199:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:210:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_0_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:197:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:198:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:218:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:229:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_0_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:216:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:217:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:246:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:257:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_0_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:244:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:245:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:241:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:243:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:264:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:275:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_0_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:262:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:263:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:259:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:261:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:282:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:293:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_0_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:280:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:281:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:277:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:279:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:295:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:297:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:309:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:320:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:307:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:308:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:340:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:351:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_2_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:338:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:339:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:359:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:370:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_2_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:357:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:358:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:387:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:398:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:385:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:386:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:382:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:384:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:405:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:416:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:403:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:404:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:400:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:402:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:423:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:434:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:421:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:422:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:418:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:420:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:436:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:438:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:450:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:461:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:448:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:449:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:481:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:492:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_3_net_0_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:479:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:480:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:500:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:511:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_3_net_0_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:498:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:499:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:528:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:539:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_3_net_net_0_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:526:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:527:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:523:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:525:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:546:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:557:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_3_net_net_0_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:544:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:545:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:541:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:543:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:564:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:575:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_3_net_net_0_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:562:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:563:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:559:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:561:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:577:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:579:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 4}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:591:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:602:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:589:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:590:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:622:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:633:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_3_net_2_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:620:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:621:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:641:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:652:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_3_net_2_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:639:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:640:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:669:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:680:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_3_net_net_2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:667:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:668:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:664:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:666:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:687:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:698:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_3_net_net_2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:685:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:686:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:682:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:684:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:705:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:716:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__cnn_cnn_3_net_net_2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:703:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:704:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:700:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:702:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:718:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:720:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:732:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:743:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:730:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:731:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:763:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:774:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(cnn_4_net_0_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
# ...
# jni/xlsr_w8a8.cpp:1509:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:1529:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:1540:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(tail_2_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:1527:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:1528:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/xlsr_w8a8.cpp:1557:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:1568:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__tail_tail_2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1555:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1556:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:1552:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1554:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1575:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:1586:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__tail_tail_2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1573:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1574:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:1570:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1572:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1593:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:1604:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__tail_tail_2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1591:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1592:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:1588:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1590:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1606:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1608:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1620:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:1631:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1618:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1619:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:1656:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:1667:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__depth_to_space_DepthToSpace_block_size,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1654:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1655:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:1651:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1653:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1669:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1671:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1681:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:1692:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1679:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1680:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/xlsr_w8a8.cpp:1710:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1712:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_FLOAT_32, {.floatValue = 1.000000000000f}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1713:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1715:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_FLOAT_32, {.floatValue = 0.000000000000f}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1725:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/xlsr_w8a8.cpp:1736:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1723:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/xlsr_w8a8.cpp:1724:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# 191 warnings generated.
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_0_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_0_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_2_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_2_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_3_net_0_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_3_net_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_3_net_0_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_3_net_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_3_net_2_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_3_net_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_3_net_2_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_3_net_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_4_net_0_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_4_net_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_4_net_0_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_4_net_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_4_net_2_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_4_net_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_4_net_2_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_4_net_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_5_net_0_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_5_net_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_5_net_0_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_5_net_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_5_net_2_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_5_net_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/cnn_5_net_2_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//cnn_5_net_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/residual_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//residual_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/residual_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//residual_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/tail_0_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//tail_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/tail_0_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//tail_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/tail_2_bias.raw obj/local/arm64-v8a/objs/xlsr_w8a8//tail_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/tail_2_weight.raw obj/local/arm64-v8a/objs/xlsr_w8a8//tail_2_weight.o
# [arm64-v8a] SharedLibrary  : libxlsr_w8a8.so
# [arm64-v8a] Install        : libxlsr_w8a8.so => libs/arm64-v8a/libxlsr_w8a8.so
# INFO: Output libraries saved at /local/mnt/workspace/gokul/models-for-solutions/01-super-resolution/xlsr/models/model_libs2
# INFO: Building models/xlsr_w8a8.cpp complete.
# qnn-context-binary-generator pid:287560

# %% [markdown]
# # Post-process model output

# %%
def post_process_sr(img):
#     img = img.detach().cpu().numpy()
    img = np.fromfile(img, np.float32)
    img = img.reshape((3,512, 512)).astype(np.float32)
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %% [markdown]
# # Method to calcualte PSNR

# %%
def compute_psnr(img_pred, img_true, data_range=255., eps=1e-8):
    """
    Compute PSNR between super-resolved and original images.
    
    :param img_pred:
        The super-resolved image obtained from the model
    :param img_true:
        The original high-res image
    :param data_range:
        Default = 255
    :param eps:
        Default = 1e-8
    :return:
        PSNR value
    """
    err = (img_pred - img_true) ** 2
    err = err.mean(dim=-1).mean(dim=-1)

    return 10. * torch.log10((data_range ** 2) / (err + eps))

# %%
def evaluate_psnr(y_pred, y_true):
    """
    Evaluate individual PSNR metric for each super-res and actual high-res image-pair.
    
    :param y_pred:
        The super-resolved image from the model
    :param y_true:
        The original high-res image
    :return:
        The evaluated PSNR metric for the image-pair
    """
    y_pred = y_pred.transpose(2, 0, 1)[None] / 255.
    y_true = y_true.transpose(2, 0, 1)[None] / 255.

    sr_img = convert_image(torch.FloatTensor(y_pred),
                           source='[0, 1]',
                           target='y-channel')
    hr_img = convert_image(torch.FloatTensor(y_true),
                           source='[0, 1]',
                           target='y-channel')

    return compute_psnr(sr_img, hr_img)

# %%
def evaluate_average_psnr(sr_images, hr_images):
    """
    Evaluate the avg PSNR metric for all test-set super-res and high-res images.

    :param sr_images:
        The list of super-resolved images obtained from the model for the given test-images
    :param hr_images:
        The list of original high-res test-images
    :return:
        Average PSNR metric for all super-resolved and high-res test-set image-pairs
    """
    psnr = []
    for sr_img, hr_img in zip(sr_images, hr_images):
        psnr.append(evaluate_psnr(sr_img, hr_img))

 

    # Convert the list of tensor values to a tensor array
    psnr_tensor = torch.cat(psnr)

 

    # Calculate the mean of the tensor array
    average_psnr = torch.mean(psnr_tensor)

    return average_psnr

# %% [markdown]
# # Creating Bin and Lib Folder on Device

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/bin" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/lib" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/dsp/lib"

# %% [markdown]
# # Pushing all Lib and Bin files onto Device

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/$ONDEVICE_FOLDER"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/$QNN_TARGET_STL /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/bin/$QNN_TARGET_ARCH/qnn-net-run /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/hexagon-v73/unsigned/*.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/*.so /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtp.so: 1 file pushed, 0 skipped. 392.5 MB/s (1545520 bytes in 0.004s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/bin/aarch64-android/qnn-net-run: 1 file pushed, 0 skipped. 420.8 MB/s (1441208 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libCalculator_skel.so: 1 file pushed, 0 skipped. 167.2 MB/s (7128 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73QemuDriver.so: 1 file pushed, 0 skipped. 501.5 MB/s (7601584 bytes in 0.014s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73Skel.so: 1 file pushed, 0 skipped. 524.5 MB/s (7360784 bytes in 0.013s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73.so: 1 file pushed, 0 skipped. 528.0 MB/s (8025008 bytes in 0.014s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSaver.so: 1 file pushed, 0 skipped. 416.2 MB/s (280044 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSystem.so: 1 file pushed, 0 skipped. 958.1 MB/s (56360 bytes in 0.000s)
# 6 files pushed, 0 skipped. 240.8 MB/s (23330908 bytes in 0.092s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libhta_hexagon_runtime_qnn.so: 1 file pushed, 0 skipped. 448.1 MB/s (2789832 bytes in 0.006s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnChrometraceProfilingReader.so: 1 file pushed, 0 skipped. 427.1 MB/s (516568 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnCpu.so: 1 file pushed, 0 skipped. 529.9 MB/s (4822376 bytes in 0.009s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspNetRunExtensions.so: 1 file pushed, 0 skipped. 499.0 MB/s (634024 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDsp.so: 1 file pushed, 0 skipped. 455.7 MB/s (1238520 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66CalculatorStub.so: 1 file pushed, 0 skipped. 438.4 MB/s (6368 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66Stub.so: 1 file pushed, 0 skipped. 465.7 MB/s (278216 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuNetRunExtensions.so: 1 file pushed, 0 skipped. 505.3 MB/s (626472 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuProfilingReader.so: 1 file pushed, 0 skipped. 493.3 MB/s (517864 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQn
# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="xlsr"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="xlsr_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_Quant_DSP
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnHtp.so --input_list input.txt --retrieve_context ${QUANTIZED_MODEL_NAME}.serialized.bin --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:13677
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/xlsr" (ignoring)
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/xlsr" (ignoring)

# %% [markdown]
# # Inferencing 32b DLC on CPU Runtime
# Give name of DLC in OUTPUT_DLC_32 and ondevice folder

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="xlsr"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="xlsr_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_CPU
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnCpu.so --input_list input.txt --model lib${QUANTIZED_MODEL_NAME}.so --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:13684

# %% [markdown]
# # Pulling Output folder generated on different precision and cores

# %%
# %%bash
# rm -rf OUTPUT_Quant_DSP
# rm -rf OUTPUT_CPU

# %%
# %%bash
#
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_Quant_DSP output/OUTPUT_Quant_DSP
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_CPU output/OUTPUT_CPU
# Out:
# /data/local/tmp/xlsr/OUTPUT_Quant_DSP/: 14 files pulled, 0 skipped. 103.2 MB/s (44040192 bytes in 0.407s)
# /data/local/tmp/xlsr/OUTPUT_CPU/: 14 files pulled, 0 skipped. 107.3 MB/s (44040192 bytes in 0.391s)

# %% [markdown]
# # Calculate PSNR
# * Pass path of two raw image in Argument.

# %%
val = []
for i in range(10):
    val.append(IMAGES_HR[i])
val[0].shape
# Out:
# (512, 512, 3)

# %%
folder = ["output/OUTPUT_Quant_DSP","output/OUTPUT_CPU"]
RGB_WEIGHTS = torch.FloatTensor([65.481, 128.553, 24.966])
for j in range(0,len(folder)):
    IMAGES_SR = []
    for i in range(0,10):
        IMAGES_SR.append(post_process_sr(folder[j]+"/Result_"+str(i)+"/_43.raw"))
    print(folder[j]," (Average PSNR) :: ",evaluate_average_psnr(IMAGES_SR, IMAGES_HR))
    print("\n============================\n")
# Out:
# output/OUTPUT_Quant_DSP  (Average PSNR) ::  tensor(20.8536)
#
# ============================
#
# output/OUTPUT_CPU  (Average PSNR) ::  tensor(20.8550)
#
# ============================

# %%
import matplotlib.pyplot as plt
plt.imshow(IMAGES_SR[5])

# %%
plt.imshow(IMAGES_HR[5])
