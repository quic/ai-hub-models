# %% [markdown]
# # Setting Up All Artifacts details

# %%
import os
os.environ['QNN_SDK_ROOT']="/local/mnt/workspace/gokul/QNN/2.19.0.240124" #set up your qnn path here.
os.environ['ANDROID_NDK_ROOT']="/local/mnt/workspace/gokul/android-ndk-r25c"
os.environ['RAW_FILE_FOLDER']="raw"
os.environ['FOLDER_WITH_ARTIFACTS']="StableLLVE"
os.environ['ONDEVICE_FOLDER']="StableLLVE"
os.environ['MODEL_NAME']="StableLLVE_fp32"
os.environ['QUANTIZED_MODEL_NAME']="StableLLVE_w8a8"
os.environ['MODEL_PATH']="models/StableLLVE_fp32"
os.environ['QUANTIZED_MODEL_PATH']="models/StableLLVE_w8a8"
os.environ['TARGET_INPUT_LIST']="list.txt"
os.environ['DEVICE_HOST']="localhost"
os.environ['DEVICE_ID']="bc468c1d" #fill your device-id. Use command "adb devices" to get devices names. example :"e18d5d0"
os.environ['QNN_TARGET_ARCH']="aarch64-android"
os.environ['QNN_TARGET_STL']="libQnnHtp.so"

# %%
# %%bash
# git clone https://github.com/zkawfanx/StableLLVE.git

# %%
# %%bash
# cp generate_model.py StableLLVE/
# cd StableLLVE
# python generate_model.py
# Out:
# /local/mnt/workspace/gokul/gokul-env/lib/python3.8/site-packages/torch/onnx/utils.py:702: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /local/mnt/workspace/gokul/gokul-env/lib/python3.8/site-packages/torch/onnx/utils.py:1209: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# ONNX model saved Successfully

# %% [markdown]
# #### Getting the Non Quantized DLC File

# %% [markdown]
# #### Understanding the Architecture of the Model

# %% [markdown]
# Use the dataset of your choice to validate the pre-processing, and post processing steps given in this notebook

# %%
def preprocess(ll_img, hl_img):
    ll_img = np.array(ll_img, dtype='float32')
    hl_img = np.array(hl_img, dtype='float32')   
    ll_img = np.uint8(np.clip(ll_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    hl_img = np.uint8(np.clip(hl_img, 0., 255.))  # this is to simulate matlab's imwrite operation 
    ll_img = np.uint8(ll_img)
    hl_img = np.uint8(hl_img)
    ll_img = convert_image(ll_img, source='array', target='[0, 1]')
    hl_img = convert_image(hl_img, source='array', target='[0, 1]')
    return ll_img, hl_img

# %% [markdown]
# ## Preprocessing the data to generate raw file

# %%
def convert_image(img, source, target):
    if source == 'array':
        img = torch.from_numpy(img.transpose((2, 0, 1))).contiguous()#chw
        img = img.to(dtype=torch.float32).div(255) 
    elif source == '[0, 1]':
        img = torch.clamp(img, 0, 1)  # useful to post-process output of models that can overspill
    
    if target == '[0, 1]':
        pass  # already in [0, 1]
    return img

# %%
def post_process(img):
    img = img.detach().cpu().numpy()
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %%
def load_dataset(test_images_dir):
    # Input images for the model
    INPUTS_LL = []
    # Post-processed images for visualization
    IMAGES_LL = [] # LL:Low Light
    IMAGES_HL = [] # HL:High Light

    # Load the test images
    count=0
    for img_path in glob.glob(os.path.join(test_images_dir, '*')):
        l_img = cv2.resize(cv2.imread(img_path),[480,640],interpolation=cv2.INTER_CUBIC)
        l_img = cv2.cvtColor(l_img, cv2.COLOR_BGR2RGB)
        
        h_img = cv2.resize(cv2.imread(img_path.replace("low","high")),[480,640],interpolation=cv2.INTER_CUBIC)
        h_img = cv2.cvtColor(h_img, cv2.COLOR_BGR2RGB)
        
        ll_img, hl_img = preprocess(l_img, h_img)#chw

        INPUTS_LL.append(ll_img)#chw
        IMAGES_LL.append(post_process(ll_img))#hwc
        IMAGES_HL.append(post_process(hl_img))#hwc
    return INPUTS_LL, IMAGES_LL, IMAGES_HL

# %% [markdown]
# **Converting the low dataset to raw file format to give it to the model and do the inference**

# %%
os.makedirs('raw', exist_ok=True)

# %%
import glob
import os
import cv2
import numpy as np
import torch

test_images_dir = "eval15/low"
INPUTS_LL, IMAGES_LL, IMAGES_HL = load_dataset(test_images_dir)
print(len(INPUTS_LL),len(IMAGES_LL),len(IMAGES_HL))
for i, img_ll in enumerate(INPUTS_LL):
    img_ll = img_ll.cpu().detach().numpy()
    img_ll = img_ll.astype(np.float32)
    fid = open("raw/img_"+str(i)+ ".raw", 'wb')
    img_ll.tofile(fid)
    fid.close()
# Out:
# 0 0 0

# %%
def post_process_enhanced(img):
    img = np.fromfile(img, np.float32)
    img = img.reshape((3,640,480)).astype(np.float32)
    img = np.clip(img* 255. , 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %% [markdown]
# #### Getting the Quantized Model

# %%
total_iter = 15
print("Generating input_list \"small_raw_list.txt\" with {} iterations".format(total_iter))
with open("list.txt",'w') as f:
    for i in range(total_iter):
        f.write("raw/img_{}.raw\n".format(i))
# Out:
# Generating input_list "small_raw_list.txt" with 15 iterations

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network StableLLVE.onnx --output_path ${MODEL_PATH}.cpp
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${MODEL_PATH}.cpp -b ${MODEL_PATH}.bin -o models/model_libs
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs/x86_64-linux-clang/lib${MODEL_NAME}.so \
#               --binary_file ${MODEL_NAME}.serialized

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network StableLLVE.onnx --output_path ${QUANTIZED_MODEL_PATH}.cpp --input_list list.txt \
#                 --param_quantizer "adjusted" --act_quantizer "enhanced"
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${QUANTIZED_MODEL_PATH}.cpp -b ${QUANTIZED_MODEL_PATH}.bin -o models/model_libs2
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs2/x86_64-linux-clang/lib${QUANTIZED_MODEL_NAME}.so \
#               --binary_file ${QUANTIZED_MODEL_NAME}.serialized
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# 2024-03-04 09:44:17,228 - 235 - INFO - Simplified model validation is successful
# 2024-03-04 09:44:18,444 - 235 - INFO - Saving QNN Model...
# IrQuantizer: Quantizer param type: adjusted will be deprecated in future releases
# IrQuantizer: Quantizer type: adjusted is no longer supported. Using TF quantizer instead
# 2024-03-04 09:44:37,127 - 235 - INFO - Model CPP saved at: models/StableLLVE_w8a8.cpp
# 2024-03-04 09:44:37,128 - 235 - INFO - Model BIN saved at: /local/mnt/workspace/gokul/models-for-solutions/02-low-light-enhancement/StableLLVE/models/StableLLVE_w8a8.bin
# 2024-03-04 09:44:37,128 - 235 - INFO - Conversion complete!
#      0.1ms [  INFO ] Inferences will run in sync mode
#      0.1ms [  INFO ] Initializing logging in the backend. Callback: [0x7fb5d8ff2e10], Log Level: [3]
#      0.1ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.2ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.2ms [  INFO ] Entering QuantizeRuntimeApp flow
#      4.3ms [  INFO ] CpuGraph::finalize
#    288.8ms [  INFO ] CpuGraph::execute
#   1794.6ms [  INFO ] cleaning up resources for input tensors
#   1794.6ms [  INFO ] cleaning up resources for output tensors
#   1819.3ms [  INFO ] CpuGraph::execute
#   2959.3ms [  INFO ] cleaning up resources for input tensors
#   2959.3ms [  INFO ] cleaning up resources for output tensors
#   2981.4ms [  INFO ] CpuGraph::execute
#   4153.4ms [  INFO ] cleaning up resources for input tensors
#   4153.5ms [  INFO ] cleaning up resources for output tensors
#   4171.1ms [  INFO ] CpuGraph::execute
#   5378.5ms [  INFO ] cleaning up resources for input tensors
#   5378.5ms [  INFO ] cleaning up resources for output tensors
#   5398.5ms [  INFO ] CpuGraph::execute
#   6567.7ms [  INFO ] cleaning up resources for input tensors
#   6567.8ms [  INFO ] cleaning up resources for output tensors
#   6590.0ms [  INFO ] CpuGraph::execute
#   7731.1ms [  INFO ] cleaning up resources for input tensors
#   7731.1ms [  INFO ] cleaning up resources for output tensors
#   7742.8ms [  INFO ] CpuGraph::execute
#   8909.7ms [  INFO ] cleaning up resources for input tensors
#   8909.7ms [  INFO ] cleaning up resources for output tensors
#   8932.5ms [  INFO ] CpuGraph::execute
#  10077.5ms [  INFO ] cleaning up resources for input tensors
#  10077.5ms [  INFO ] cleaning up resources for output tensors
#  10100.2ms [  INFO ] CpuGraph::execute
#  11309.4ms [  INFO ] cleaning up resources for input tensors
#  11309.4ms [  INFO ] cleaning up resources for output tensors
#  11333.7ms [  INFO ] CpuGraph::execute
#  12543.4ms [  INFO ] cleaning up resources for input tensors
#  12543.4ms [  INFO ] cleaning up resources for output tensors
#  12560.6ms [  INFO ] CpuGraph::execute
#  13708.1ms [  INFO ] cleaning up resources for input tensors
#  13708.1ms [  INFO ] cleaning up resources for output tensors
#  13729.8ms [  INFO ] CpuGraph::execute
#  14889.9ms [  INFO ] cleaning up resources for input tensors
#  14889.9ms [  INFO ] cleaning up resources for output tensors
#  14912.1ms [  INFO ] CpuGraph::execute
#  16077.3ms [  INFO ] cleaning up resources for input tensors
#  16077.3ms [  INFO ] cleaning up resources for output tensors
#  16094.9ms [  INFO ] CpuGraph::execute
#  17390.2ms [  INFO ] cleaning up resources for input tensors
#  17390.2ms [  INFO ] cleaning up resources for output tensors
#  17400.0ms [  INFO ] CpuGraph::execute
#  18566.8ms [  INFO ] cleaning up resources for input tensors
#  18566.8ms [  INFO ] cleaning up resources for output tensors
#  18611.3ms [  INFO ] Freeing graphsInfo
#
# --------------------------
# INFO: Building for target: x86_64-linux-clang
# --------------------------
# mkdir -p obj/x86_64-linux-clang
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModel.cpp -o obj/x86_64-linux-clang/QnnModel.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModelPal.cpp -o obj/x86_64-linux-clang/QnnModelPal.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnWrapperUtils.cpp -o obj/x86_64-linux-clang/QnnWrapperUtils.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/StableLLVE_w8a8.cpp -o obj/x86_64-linux-clang/StableLLVE_w8a8.o
# mkdir -p obj/binary/x86_64-linux-clang
# touch obj/binary/extractbinary
# mkdir -p libs/x86_64-linux-clang
#
# --------------------------
# INFO: Building for target: aarch64-android
# --------------------------
# Android NDK: android-16 is unsupported. Using minimum supported version android-19.
# Android NDK: WARNING: Unsupported source file extensions in jni/Android.mk for module StableLLVE_w8a8
# Android NDK:   /down1_maxpool_conv_1_double_conv_0_bias.o /down1_maxpool_conv_1_double_conv_0_weight.o /down1_maxpool_conv_1_double_conv_2_bias.o /down1_maxpool_conv_1_double_conv_2_weight.o /down2_maxpool_conv_1_double_conv_0_bias.o /down2_maxpool_conv_1_double_conv_0_weight.o /down2_maxpool_conv_1_double_conv_2_bias.o /down2_maxpool_conv_1_double_conv_2_weight.o /down3_maxpool_conv_1_double_conv_0_bias.o /down3_maxpool_conv_1_double_conv_0_weight.o /down3_maxpool_conv_1_double_conv_2_bias.o /down3_maxpool_conv_1_double_conv_2_weight.o /down4_maxpool_conv_1_double_conv_0_bias.o /down4_maxpool_conv_1_double_conv_0_weight.o /down4_maxpool_conv_1_double_conv_2_bias.o /down4_maxpool_conv_1_double_conv_2_weight.o /inc_double_conv_0_bias.o /inc_double_conv_0_weight.o /inc_double_conv_2_bias.o /inc_double_conv_2_weight.o /outc_conv_bias.o /outc_conv_weight.o /up1_conv_double_conv_0_bias.o /up1_conv_double_conv_0_weight.o /up1_conv_double_conv_2_bias.o /up1_conv_double_conv_2_weight.o /up2_conv_double_conv_0_bias.o /up2_conv_double_conv_0_weight.o /up2_conv_double_conv_2_bias.o /up2_conv_double_conv_2_weight.o /up3_conv_double_conv_0_bias.o /up3_conv_double_conv_0_weight.o /up3_conv_double_conv_2_bias.o /up3_conv_double_conv_2_weight.o /up4_conv_double_conv_0_bias.o /up4_conv_double_conv_0_weight.o /up4_conv_double_conv_2_bias.o /up4_conv_double_conv_2_weight.o
# [arm64-v8a] Compile++      : StableLLVE_w8a8 <= QnnModel.cpp
# [arm64-v8a] Compile++      : StableLLVE_w8a8 <= QnnModelPal.cpp
# [arm64-v8a] Compile++      : StableLLVE_w8a8 <= QnnWrapperUtils.cpp
# [arm64-v8a] Compile++      : StableLLVE_w8a8 <= StableLLVE_w8a8.cpp
# jni/StableLLVE_w8a8.cpp:39:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:50:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=nullptr,
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:37:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:38:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:58:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:69:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(inc_double_conv_0_weight),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:56:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:57:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:77:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:88:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(inc_double_conv_0_bias),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:75:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:76:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:105:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:116:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__inc_double_conv_double_conv_0_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:103:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:104:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:100:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:102:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:123:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:134:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__inc_double_conv_double_conv_0_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:121:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:122:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:118:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:120:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:141:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:152:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__inc_double_conv_double_conv_0_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:139:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:140:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:136:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:138:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:154:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:156:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:168:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:179:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:166:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:167:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:199:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:210:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(inc_double_conv_2_weight),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:197:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:198:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:218:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:229:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(inc_double_conv_2_bias),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:216:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:217:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:246:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:257:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__inc_double_conv_double_conv_2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:244:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:245:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:241:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:243:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:264:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:275:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__inc_double_conv_double_conv_2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:262:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:263:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:259:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:261:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:282:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:293:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__inc_double_conv_double_conv_2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:280:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:281:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:277:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:279:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:295:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:297:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:309:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:320:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:307:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:308:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:349:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:360:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_0_MaxPool_filter_size,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:347:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:348:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:344:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:346:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:367:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:378:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_0_MaxPool_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:365:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:366:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:362:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:364:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:385:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:396:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_0_MaxPool_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:383:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:384:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:380:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:382:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:407:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:418:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:405:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:406:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:438:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:449:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(down1_maxpool_conv_1_double_conv_0_weight),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:436:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:437:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:457:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:468:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(down1_maxpool_conv_1_double_conv_0_bias),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:455:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:456:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:485:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:496:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_1_double_conv_double_conv_0_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:483:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:484:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:480:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:482:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:503:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:514:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_1_double_conv_double_conv_0_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:501:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:502:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:498:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:500:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:521:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:532:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_1_double_conv_double_conv_0_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:519:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:520:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:516:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:518:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:534:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:536:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:548:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:559:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:546:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:547:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:579:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:590:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(down1_maxpool_conv_1_double_conv_2_weight),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:577:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:578:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:598:44: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                            .id=0,
#                                            ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:609:44: note: first non-designated initializer is here
#                                            {.clientBuf= { .data=BINVARSTART(down1_maxpool_conv_1_double_conv_2_bias),
#                                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:596:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:597:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:626:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:637:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_1_double_conv_double_conv_2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:624:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:625:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:621:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:623:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:644:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:655:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_1_double_conv_double_conv_2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:642:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:643:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:639:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:641:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:662:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:673:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down1_maxpool_conv_maxpool_conv_1_double_conv_double_conv_2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:660:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:661:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:657:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:659:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:675:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:677:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:689:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:700:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:687:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:688:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:729:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:740:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__down2_maxpool_conv_maxpool_conv_0_MaxPool_filter_size,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:727:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:728:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# ...
#                                          .version= QNN_TENSOR_VERSION_1,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:3350:42: note: first non-designated initializer is here
#                                          {.v1= {
#                                          ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/StableLLVE_w8a8.cpp:3379:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:3390:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__outc_conv_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3377:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3378:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:3374:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3376:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3397:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:3408:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__outc_conv_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3395:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3396:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:3392:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3394:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3415:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:3426:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__outc_conv_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3413:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3414:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/StableLLVE_w8a8.cpp:3410:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3412:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3428:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3430:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3442:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/StableLLVE_w8a8.cpp:3453:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3440:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/StableLLVE_w8a8.cpp:3441:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# 378 warnings generated.
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down1_maxpool_conv_1_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down1_maxpool_conv_1_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down1_maxpool_conv_1_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down1_maxpool_conv_1_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down1_maxpool_conv_1_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down1_maxpool_conv_1_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down1_maxpool_conv_1_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down1_maxpool_conv_1_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down2_maxpool_conv_1_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down2_maxpool_conv_1_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down2_maxpool_conv_1_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down2_maxpool_conv_1_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down2_maxpool_conv_1_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down2_maxpool_conv_1_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down2_maxpool_conv_1_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down2_maxpool_conv_1_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down3_maxpool_conv_1_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down3_maxpool_conv_1_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down3_maxpool_conv_1_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down3_maxpool_conv_1_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down3_maxpool_conv_1_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down3_maxpool_conv_1_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down3_maxpool_conv_1_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down3_maxpool_conv_1_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down4_maxpool_conv_1_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down4_maxpool_conv_1_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down4_maxpool_conv_1_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down4_maxpool_conv_1_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down4_maxpool_conv_1_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down4_maxpool_conv_1_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/down4_maxpool_conv_1_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//down4_maxpool_conv_1_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/inc_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//inc_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/inc_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//inc_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/inc_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//inc_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/inc_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//inc_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/outc_conv_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//outc_conv_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/outc_conv_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//outc_conv_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up1_conv_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up1_conv_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up1_conv_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up1_conv_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up1_conv_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up1_conv_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up1_conv_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up1_conv_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up2_conv_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up2_conv_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up2_conv_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up2_conv_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up2_conv_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up2_conv_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up2_conv_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up2_conv_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up3_conv_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up3_conv_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up3_conv_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up3_conv_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up3_conv_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up3_conv_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up3_conv_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up3_conv_double_conv_2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up4_conv_double_conv_0_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up4_conv_double_conv_0_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up4_conv_double_conv_0_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up4_conv_double_conv_0_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up4_conv_double_conv_2_bias.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up4_conv_double_conv_2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/up4_conv_double_conv_2_weight.raw obj/local/arm64-v8a/objs/StableLLVE_w8a8//up4_conv_double_conv_2_weight.o
# [arm64-v8a] SharedLibrary  : libStableLLVE_w8a8.so
# [arm64-v8a] Install        : libStableLLVE_w8a8.so => libs/arm64-v8a/libStableLLVE_w8a8.so
# INFO: Output libraries saved at /local/mnt/workspace/gokul/models-for-solutions/02-low-light-enhancement/StableLLVE/models/model_libs2
# INFO: Building models/StableLLVE_w8a8.cpp complete.
# qnn-context-binary-generator pid:206981

# %% [markdown]
# ## Model Inference

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/bin" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/lib" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/dsp/lib"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/$ONDEVICE_FOLDER"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/$QNN_TARGET_STL /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/bin/$QNN_TARGET_ARCH/qnn-net-run /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/hexagon-v73/unsigned/*.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/*.so /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtp.so: 1 file pushed, 0 skipped. 405.5 MB/s (1545520 bytes in 0.004s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/bin/aarch64-android/qnn-net-run: 1 file pushed, 0 skipped. 408.6 MB/s (1441208 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libCalculator_skel.so: 1 file pushed, 0 skipped. 150.5 MB/s (7128 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73QemuDriver.so: 1 file pushed, 0 skipped. 495.7 MB/s (7601584 bytes in 0.015s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73Skel.so: 1 file pushed, 0 skipped. 511.7 MB/s (7360784 bytes in 0.014s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73.so: 1 file pushed, 0 skipped. 502.9 MB/s (8025008 bytes in 0.015s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSaver.so: 1 file pushed, 0 skipped. 395.3 MB/s (280044 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSystem.so: 1 file pushed, 0 skipped. 956.7 MB/s (56360 bytes in 0.000s)
# 6 files pushed, 0 skipped. 216.0 MB/s (23330908 bytes in 0.103s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libhta_hexagon_runtime_qnn.so: 1 file pushed, 0 skipped. 447.1 MB/s (2789832 bytes in 0.006s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnChrometraceProfilingReader.so: 1 file pushed, 0 skipped. 430.3 MB/s (516568 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnCpu.so: 1 file pushed, 0 skipped. 223.6 MB/s (4822376 bytes in 0.021s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspNetRunExtensions.so: 1 file pushed, 0 skipped. 373.9 MB/s (634024 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDsp.so: 1 file pushed, 0 skipped. 350.5 MB/s (1238520 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66CalculatorStub.so: 1 file pushed, 0 skipped. 58.4 MB/s (6368 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66Stub.so: 1 file pushed, 0 skipped. 299.1 MB/s (278216 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuNetRunExtensions.so: 1 file pushed, 0 skipped. 304.6 MB/s (626472 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuProfilingReader.so: 1 file pushed, 0 skipped. 326.6 MB/s (517864 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpu.so: 1 file pushed, 0 skipped. 420.2 MB/s (4484984 bytes in 0.010s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtaNetRunExtensions.so: 1 file pushed, 0 skipped. 363.1 MB/s (621800 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHta.so: 1 file pushed, 0 skipped. 370.7 MB/s (896360 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpNetRunExtensions.so: 1 file pushed, 0 skipped. 372.2 MB/s (721360 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpOptraceProfilingReader.so: 1 file pushed, 0 skipped. 365.4 MB/s (617896 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpPrepare.so: 1 file pushed, 0 skipped. 534.7 MB/s (26627504 bytes in 0.047s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpProfilingReader.so: 1 file pushed, 0 skipped. 458.5 MB/s (502584 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtp.so: 1 file pushed, 0 skipped. 474.1 MB/s (1545520 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV68CalculatorStub.so: 1 file pushed, 0 skipped. 420.4 MB/s (6416 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV68Stub.so: 1 file pushed, 0 skipped. 422.4 MB/s (281936 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV69CalculatorStub.so: 1 file pushed, 0 skipped. 467.0 MB/s (6416 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV69Stub.so: 1 file pushed, 0 skipped. 445.5 MB/s (282816 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV73CalculatorStub.so: 1 file pushed, 0 skipped. 410.1 MB/s (6968 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV73Stub.so: 1 file pushed, 0 skipped. 441.6 MB/s (290408 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV75CalculatorStub.so: 1 file pushed, 0 skipped. 531.4 MB/s (6968 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV75Stub.so: 1 file pushed, 0 skipped. 448.2 MB/s (290408 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnJsonProfilingReader.so: 1 file pushed, 0 skipped. 489.3 MB/s (521504 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnModelDlc.so: 1 file pushed, 0 skipped. 465.3 MB/s (1598240 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSaver.so: 1 file pushed, 0 skipped. 461.4 MB/s (689360 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSystem.so: 1 file pushed, 0 skipped. 427.4 MB/s (229024 bytes in 0.001s)
# 29 files pushed, 0 skipped. 281.4 MB/s (51658712 bytes in 0.175s)

# %%
# %%bash
# #find ./raw -name *.raw > list.txt
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push output/${QUANTIZED_MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push output/${MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push models/model_libs2/aarch64-android/lib${QUANTIZED_MODEL_NAME}.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $RAW_FILE_FOLDER /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $TARGET_INPUT_LIST /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# output/StableLLVE_w8a8.serialized.bin: 1 file pushed, 0 skipped. 748.1 MB/s (4856800 bytes in 0.006s)
# output/StableLLVE_fp32.serialized.bin: 1 file pushed, 0 skipped. 226.8 MB/s (17633544 bytes in 0.074s)
# models/model_libs2/aarch64-android/libStableLLVE_w8a8.so: 1 file pushed, 0 skipped. 489.0 MB/s (4714928 bytes in 0.009s)
# raw/: 15 files pushed, 0 skipped. 305.5 MB/s (55296000 bytes in 0.173s)
# list.txt: 1 file pushed, 0 skipped. 5.2 MB/s (215 bytes in 0.000s)

# %% [markdown]
# #### Inferencing the Quantized Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="StableLLVE"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="StableLLVE_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_Quant_DSP
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnHtp.so --input_list list.txt --retrieve_context ${QUANTIZED_MODEL_NAME}.serialized.bin --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:13074
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/StableLLVE" (ignoring)
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/StableLLVE" (ignoring)

# %% [markdown]
# #### Inferencing the Non-Quantized Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="StableLLVE"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="StableLLVE_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_CPU
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnCpu.so --input_list list.txt --model lib${QUANTIZED_MODEL_NAME}.so --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:13081

# %%
# %%bash
# rm -rf OUTPUT_Quant_DSP
# rm -rf OUTPUT_CPU

# %% [markdown]
# #### Pulling the Output

# %%
# %%bash
#
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_Quant_DSP output/OUTPUT_Quant_DSP
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_CPU output/OUTPUT_CPU
# Out:
# /data/local/tmp/StableLLVE/OUTPUT_Quant_DSP/: 15 files pulled, 0 skipped. 127.6 MB/s (55296000 bytes in 0.413s)
# /data/local/tmp/StableLLVE/OUTPUT_CPU/: 15 files pulled, 0 skipped. 171.2 MB/s (55296000 bytes in 0.308s)

# %% [markdown]
# ### Post Processing and Calculating PSNR Value

# %%
import math
def compute_psnr(img_pred, img_true, data_range=255., eps=1e-8):
    err = (img_pred - img_true) ** 2 
    err = np.mean(err)
    return 10. * math.log10((data_range ** 2) / (err + eps))

# %%
def evaluate_average_psnr(el_images, hl_images): #(enhanced_light<model o/p>, high_light <groud_truth>)
    psnr = []
    for i in range(len(el_images)):
        el_img = cv2.imread(el_images[i], 1)
        hl_img = cv2.imread(hl_images[i], 1)
        psnr.append(compute_psnr(el_img,hl_img))
    average_psnr = np.mean(np.array(psnr))
    return average_psnr
