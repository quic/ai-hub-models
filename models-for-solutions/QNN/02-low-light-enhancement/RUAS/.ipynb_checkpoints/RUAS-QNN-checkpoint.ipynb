# %% [markdown]
# # Setting Up All Artifacts details

# %%
import os
os.environ['QNN_SDK_ROOT']="/local/mnt/workspace/gokul/QNN/2.19.0.240124" #set up your qnn path here.
os.environ['ANDROID_NDK_ROOT']="/local/mnt/workspace/gokul/android-ndk-r25c"
os.environ['RAW_FILE_FOLDER']="raw"
os.environ['FOLDER_WITH_ARTIFACTS']="RUAS"
os.environ['MODEL_NAME']="ruas_fp32"
os.environ['QUANTIZED_MODEL_NAME']="ruas_w8a8"
os.environ['MODEL_PATH']="models/ruas_fp32"
os.environ['QUANTIZED_MODEL_PATH']="models/ruas_w8a8"
os.environ['TARGET_INPUT_LIST']="list.txt"
os.environ['ONDEVICE_FOLDER']="RUAS"
os.environ['DEVICE_HOST']="localhost"
os.environ['DEVICE_ID']="bc468c1d" #fill your device-id. Use command "adb devices" to get devices names. example :"e18d5d0"
os.environ['QNN_TARGET_ARCH']="aarch64-android"
os.environ['QNN_TARGET_STL']="libQnnHtp.so"

# %%
from PIL import Image
import glob
import os
import cv2
import numpy as np
import torch
import os
import shutil

# %% [markdown]
# # Getting The Model
#
# - **If You Already have the models in the dlc folder no need to run this cell**
# - [ https://github.com/dut-media-lab/RUAS.git  ](Link of the Actual Model)
# - Retinex-inspired Unrolling with Cooperative Prior Architecture Search for Low-light Image Enhancement(RUAS)

# %%
# %%bash
# git clone https://github.com/dut-media-lab/RUAS
# git reset --hard c859661f89b21bce592634b36ecec33fa6bb4b19

# %%
command1="cp RUAS.patch RUAS/;cd RUAS;patch -i RUAS.patch"
os.system(command1)
# Out:
# patching file model.py
# Reversed (or previously applied) patch detected!  Assume -R? [n]
# Apply anyway? [n]
# Skipping patch.
# 1 out of 1 hunk ignored -- saving rejects to file model.py.rej
# 256

# %% [markdown]
# #### Generating the ONNX Model
# - **Before Running this cell change  in generate_model.py the torch.load(RUAS/ckpt/lol.pt) to torch.load(ckpt/lol.pt)**

# %%
# %%bash
# cp generate_model.py RUAS/
# cd RUAS
# cp model/denoise.pt ckpt/
# python generate_model.py
# #cp -r ruas.onnx ../
# Out:
# /local/mnt/workspace/gokul/gokul-env/lib/python3.8/site-packages/torch/onnx/_internal/jit_utils.py:307: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /local/mnt/workspace/gokul/gokul-env/lib/python3.8/site-packages/torch/onnx/utils.py:702: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /local/mnt/workspace/gokul/gokul-env/lib/python3.8/site-packages/torch/onnx/utils.py:1209: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# ONNX model saved successfully

# %% [markdown]
# #### Getting DLC(32b) Model

# %% [markdown]
# ##### Understanding the Model architecture

# %% [markdown]
# ## Getting Dataset
#
# Use the dataset of your choice to validate the pre-processing, and post processing steps given in this notebook

# %% [markdown]
# ## Preprocessing the data to generate raw file

# %%
def preprocess(ll_img, hl_img):
    ll_img = np.array(ll_img, dtype='float32')
    hl_img = np.array(hl_img, dtype='float32')
    
    ll_img = np.uint8(np.clip(ll_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    hl_img = np.uint8(np.clip(hl_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    
    ll_img = np.uint8(ll_img)
    hl_img = np.uint8(hl_img)
    
    ll_img = convert_image(ll_img, source='array', target='[0, 1]')
    hl_img = convert_image(hl_img, source='array', target='[0, 1]')
    
    return ll_img, hl_img

# %%
def convert_image(img, source, target):
    if source == 'array':
        img = torch.from_numpy(img.transpose((2, 0, 1))).contiguous()#chw
        img = img.to(dtype=torch.float32).div(255) 
    elif source == '[0, 1]':
        img = torch.clamp(img, 0, 1)  # useful to post-process output of models that can overspill
    
    if target == '[0, 1]':
        pass  # already in [0, 1]
    return img

# %%
def post_process(img):
    img = img.detach().cpu().numpy()
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %%
def load_dataset(test_images_dir):
    # Input images for the model
    INPUTS_LL = []
    # Post-processed images for visualization
    IMAGES_LL = [] # LL:Low Light
    IMAGES_HL = [] # HL:High Light

    # Load the test images
    count=0
    for img_path in glob.glob(os.path.join(test_images_dir, '*')):
        l_img = cv2.resize(cv2.imread(img_path),[480,640],interpolation=cv2.INTER_CUBIC)
        l_img = cv2.cvtColor(l_img, cv2.COLOR_BGR2RGB)
        
        h_img = cv2.resize(cv2.imread(img_path.replace("low","high")),[480,640],interpolation=cv2.INTER_CUBIC)
        h_img = cv2.cvtColor(h_img, cv2.COLOR_BGR2RGB)
        
        ll_img, hl_img = preprocess(l_img, h_img)#chw

        INPUTS_LL.append(ll_img)#chw
        IMAGES_LL.append(post_process(ll_img))#hwc
        IMAGES_HL.append(post_process(hl_img))#hwc
    return INPUTS_LL, IMAGES_LL, IMAGES_HL

# %% [markdown]
# **Converting the low dataset to raw file format to give it to the model and do the inference**

# %%
os.makedirs('raw', exist_ok=True)

# %%
test_images_dir = "<images_path>"
INPUTS_LL, IMAGES_LL, IMAGES_HL = load_dataset(test_images_dir)
print(len(INPUTS_LL),len(IMAGES_LL),len(IMAGES_HL))
for i, img_ll in enumerate(INPUTS_LL):
    img_ll = img_ll.cpu().detach().numpy()
    img_ll = img_ll.astype(np.float32)
    fid = open("raw/img_"+str(i)+ ".raw", 'wb')
    img_ll.tofile(fid)
    fid.close()
# Out:
# 0 0 0

# %% [markdown]
# #### Getting the Quantized Model

# %%
total_iter = 15
print("Generating input_list \"small_raw_list.txt\" with {} iterations".format(total_iter))
with open("list.txt",'w') as f:
    for i in range(total_iter):
        f.write("raw/img_{}.raw\n".format(i))
# Out:
# Generating input_list "small_raw_list.txt" with 15 iterations

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network ruas.onnx --output_path ${MODEL_PATH}.cpp
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${MODEL_PATH}.cpp -b ${MODEL_PATH}.bin -o models/model_libs
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs/x86_64-linux-clang/lib${MODEL_NAME}.so \
#               --binary_file ${MODEL_NAME}.serialized

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network ruas.onnx --output_path ${QUANTIZED_MODEL_PATH}.cpp --input_list list.txt \
#                 --param_quantizer "adjusted" --act_quantizer "enhanced"
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${QUANTIZED_MODEL_PATH}.cpp -b ${QUANTIZED_MODEL_PATH}.bin -o models/model_libs2
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs2/x86_64-linux-clang/lib${QUANTIZED_MODEL_NAME}.so \
#               --binary_file ${QUANTIZED_MODEL_NAME}.serialized
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# 2024-03-04 09:36:48,201 - 235 - INFO - Simplified model validation is successful
# 2024-03-04 09:36:48,213 - 240 - WARNING - Duplicate naming found in the graph.
# 2024-03-04 09:36:48,971 - 240 - WARNING - Duplicate naming found in the graph.
# 2024-03-04 09:36:49,627 - 235 - INFO - Saving QNN Model...
# IrQuantizer: Quantizer param type: adjusted will be deprecated in future releases
# IrQuantizer: Quantizer type: adjusted is no longer supported. Using TF quantizer instead
# 2024-03-04 09:37:07,630 - 235 - INFO - Model CPP saved at: models/ruas_w8a8.cpp
# 2024-03-04 09:37:07,631 - 235 - INFO - Model BIN saved at: /local/mnt/workspace/gokul/models-for-solutions/02-low-light-enhancement/RUAS/models/ruas_w8a8.bin
# 2024-03-04 09:37:07,633 - 235 - INFO - Conversion complete!
#      0.1ms [  INFO ] Inferences will run in sync mode
#      0.1ms [  INFO ] Initializing logging in the backend. Callback: [0x7faa3ea42e10], Log Level: [3]
#      0.1ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.2ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.2ms [  INFO ] Entering QuantizeRuntimeApp flow
#     13.1ms [  INFO ] CpuGraph::finalize
#     83.3ms [  INFO ] CpuGraph::execute
#   1589.3ms [  INFO ] cleaning up resources for input tensors
#   1589.4ms [  INFO ] cleaning up resources for output tensors
#   1630.0ms [  INFO ] CpuGraph::execute
#   2732.5ms [  INFO ] cleaning up resources for input tensors
#   2732.5ms [  INFO ] cleaning up resources for output tensors
#   2767.3ms [  INFO ] CpuGraph::execute
#   3867.1ms [  INFO ] cleaning up resources for input tensors
#   3867.1ms [  INFO ] cleaning up resources for output tensors
#   3892.2ms [  INFO ] CpuGraph::execute
#   5047.5ms [  INFO ] cleaning up resources for input tensors
#   5047.5ms [  INFO ] cleaning up resources for output tensors
#   5081.3ms [  INFO ] CpuGraph::execute
#   6286.2ms [  INFO ] cleaning up resources for input tensors
#   6286.2ms [  INFO ] cleaning up resources for output tensors
#   6318.7ms [  INFO ] CpuGraph::execute
#   7415.2ms [  INFO ] cleaning up resources for input tensors
#   7415.2ms [  INFO ] cleaning up resources for output tensors
#   7440.1ms [  INFO ] CpuGraph::execute
#   8551.7ms [  INFO ] cleaning up resources for input tensors
#   8551.7ms [  INFO ] cleaning up resources for output tensors
#   8583.5ms [  INFO ] CpuGraph::execute
#   9674.4ms [  INFO ] cleaning up resources for input tensors
#   9674.4ms [  INFO ] cleaning up resources for output tensors
#   9709.4ms [  INFO ] CpuGraph::execute
#  10791.4ms [  INFO ] cleaning up resources for input tensors
#  10791.4ms [  INFO ] cleaning up resources for output tensors
#  10823.9ms [  INFO ] CpuGraph::execute
#  12020.2ms [  INFO ] cleaning up resources for input tensors
#  12020.2ms [  INFO ] cleaning up resources for output tensors
#  12041.0ms [  INFO ] CpuGraph::execute
#  13123.5ms [  INFO ] cleaning up resources for input tensors
#  13123.5ms [  INFO ] cleaning up resources for output tensors
#  13154.2ms [  INFO ] CpuGraph::execute
#  14273.3ms [  INFO ] cleaning up resources for input tensors
#  14273.3ms [  INFO ] cleaning up resources for output tensors
#  14294.3ms [  INFO ] CpuGraph::execute
#  15409.6ms [  INFO ] cleaning up resources for input tensors
#  15409.6ms [  INFO ] cleaning up resources for output tensors
#  15441.4ms [  INFO ] CpuGraph::execute
#  16555.2ms [  INFO ] cleaning up resources for input tensors
#  16555.2ms [  INFO ] cleaning up resources for output tensors
#  16589.9ms [  INFO ] CpuGraph::execute
#  17805.3ms [  INFO ] cleaning up resources for input tensors
#  17805.3ms [  INFO ] cleaning up resources for output tensors
#  17923.5ms [  INFO ] Freeing graphsInfo
#
# --------------------------
# INFO: Building for target: x86_64-linux-clang
# --------------------------
# mkdir -p obj/x86_64-linux-clang
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModel.cpp -o obj/x86_64-linux-clang/QnnModel.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModelPal.cpp -o obj/x86_64-linux-clang/QnnModelPal.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnWrapperUtils.cpp -o obj/x86_64-linux-clang/QnnWrapperUtils.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/ruas_w8a8.cpp -o obj/x86_64-linux-clang/ruas_w8a8.o
# mkdir -p obj/binary/x86_64-linux-clang
# touch obj/binary/extractbinary
# mkdir -p libs/x86_64-linux-clang
#
# --------------------------
# INFO: Building for target: aarch64-android
# --------------------------
# Android NDK: android-16 is unsupported. Using minimum supported version android-19.
# Android NDK: WARNING: Unsupported source file extensions in jni/Android.mk for module ruas_w8a8
# Android NDK:   /denoise_net_activate_0_bias.o /denoise_net_activate_0_weight.o /_denoise_net_nrms_0_act_1_LeakyRelu_coeff.o /_denoise_net_nrms_0_act_2_LeakyRelu_coeff.o /_denoise_net_nrms_0_act_3_LeakyRelu_coeff.o /_denoise_net_nrms_0_act_4_LeakyRelu_coeff.o /_denoise_net_nrms_0_act_5_LeakyRelu_coeff.o /_denoise_net_nrms_0_act_6_LeakyRelu_coeff.o /_denoise_net_nrms_0_act_LeakyRelu_coeff.o /denoise_net_nrms_0_c1_d_op_bias.o /denoise_net_nrms_0_c1_d_op_weight.o /denoise_net_nrms_0_c1_r_op_bias.o /denoise_net_nrms_0_c1_r_op_weight.o /denoise_net_nrms_0_c2_d_op_bias.o /denoise_net_nrms_0_c2_d_op_weight.o /denoise_net_nrms_0_c3_d_op_bias.o /denoise_net_nrms_0_c3_d_op_weight.o /denoise_net_nrms_0_c3_r_op_bias.o /denoise_net_nrms_0_c3_r_op_weight.o /denoise_net_nrms_0_c5_bias.o /denoise_net_nrms_0_c5_weight.o /_denoise_net_nrms_1_act_1_LeakyRelu_coeff.o /_denoise_net_nrms_1_act_2_LeakyRelu_coeff.o /_denoise_net_nrms_1_act_3_LeakyRelu_coeff.o /_denoise_net_nrms_1_act_4_LeakyRelu_coeff.o /_denoise_net_nrms_1_act_5_LeakyRelu_coeff.o /_denoise_net_nrms_1_act_6_LeakyRelu_coeff.o /_denoise_net_nrms_1_act_LeakyRelu_coeff.o /denoise_net_nrms_1_c1_d_op_bias.o /denoise_net_nrms_1_c1_d_op_weight.o /denoise_net_nrms_1_c1_r_op_bias.o /denoise_net_nrms_1_c1_r_op_weight.o /denoise_net_nrms_1_c2_d_op_bias.o /denoise_net_nrms_1_c2_d_op_weight.o /denoise_net_nrms_1_c3_d_op_bias.o /denoise_net_nrms_1_c3_d_op_weight.o /denoise_net_nrms_1_c3_r_op_bias.o /denoise_net_nrms_1_c3_r_op_weight.o /denoise_net_nrms_1_c5_bias.o /denoise_net_nrms_1_c5_weight.o /_denoise_net_nrms_2_act_1_LeakyRelu_coeff.o /_denoise_net_nrms_2_act_2_LeakyRelu_coeff.o /_denoise_net_nrms_2_act_3_LeakyRelu_coeff.o /_denoise_net_nrms_2_act_4_LeakyRelu_coeff.o /_denoise_net_nrms_2_act_5_LeakyRelu_coeff.o /_denoise_net_nrms_2_act_6_LeakyRelu_coeff.o /_denoise_net_nrms_2_act_LeakyRelu_coeff.o /denoise_net_nrms_2_c1_d_op_bias.o /denoise_net_nrms_2_c1_d_op_weight.o /denoise_net_nrms_2_c1_r_op_bias.o /denoise_net_nrms_2_c1_r_op_weight.o /denoise_net_nrms_2_c2_d_op_bias.o /denoise_net_nrms_2_c2_d_op_weight.o /denoise_net_nrms_2_c3_d_op_bias.o /denoise_net_nrms_2_c3_d_op_weight.o /denoise_net_nrms_2_c3_r_op_bias.o /denoise_net_nrms_2_c3_r_op_weight.o /denoise_net_nrms_2_c5_bias.o /denoise_net_nrms_2_c5_weight.o /denoise_net_stem_bias.o /denoise_net_stem_weight.o /_enhance_net_iems_0_cell_act_1_LeakyRelu_coeff.o /_enhance_net_iems_0_cell_act_2_LeakyRelu_coeff.o /_enhance_net_iems_0_cell_act_3_LeakyRelu_coeff.o /_enhance_net_iems_0_cell_act_4_LeakyRelu_coeff.o /_enhance_net_iems_0_cell_act_5_LeakyRelu_coeff.o /_enhance_net_iems_0_cell_act_6_LeakyRelu_coeff.o /_enhance_net_iems_0_cell_act_LeakyRelu_coeff.o /enhance_net_iems_0_cell_c1_r_op_bias.o /enhance_net_iems_0_cell_c1_r_op_weight.o /enhance_net_iems_0_cell_c2_d_op_bias.o /enhance_net_iems_0_cell_c2_d_op_weight.o /enhance_net_iems_0_cell_c2_r_op_bias.o /enhance_net_iems_0_cell_c2_r_op_weight.o /enhance_net_iems_0_cell_c3_d_op_bias.o /enhance_net_iems_0_cell_c3_d_op_weight.o /enhance_net_iems_0_cell_c4_op_bias.o /enhance_net_iems_0_cell_c4_op_weight.o /enhance_net_iems_0_cell_c5_bias.o /enhance_net_iems_0_cell_c5_weight.o /_enhance_net_iems_1_cell_act_1_LeakyRelu_coeff.o /_enhance_net_iems_1_cell_act_2_LeakyRelu_coeff.o /_enhance_net_iems_1_cell_act_3_LeakyRelu_coeff.o /_enhance_net_iems_1_cell_act_4_LeakyRelu_coeff.o /_enhance_net_iems_1_cell_act_5_LeakyRelu_coeff.o /_enhance_net_iems_1_cell_act_6_LeakyRelu_coeff.o /_enhance_net_iems_1_cell_act_LeakyRelu_coeff.o /enhance_net_iems_1_cell_c1_r_op_bias.o /enhance_net_iems_1_cell_c1_r_op_weight.o /enhance_net_iems_1_cell_c2_d_op_bias.o /enhance_net_iems_1_cell_c2_d_op_weight.o /enhance_net_iems_1_cell_c2_r_op_bias.o /enhance_net_iems_1_cell_c2_r_op_weight.o /enhance_net_iems_1_cell_c3_d_op_bias.o /enhance_net_iems_1_cell_c3_d_op_weight.o /enhance_net_iems_1_cell_c4_op_bias.o /enhance_net_iems_1_cell_c4_op_weight.o /enhance_net_iems_1_cell_c5_bias.o /enhance_net_iems_1_cell_c5_weight.o /_enhance_ne ...
# [arm64-v8a] Compile++      : ruas_w8a8 <= QnnModel.cpp
# [arm64-v8a] Compile++      : ruas_w8a8 <= QnnModelPal.cpp
# [arm64-v8a] Compile++      : ruas_w8a8 <= QnnWrapperUtils.cpp
# [arm64-v8a] Compile++      : ruas_w8a8 <= ruas_w8a8.cpp
# jni/ruas_w8a8.cpp:39:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:50:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=nullptr,
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:37:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:38:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:63:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:74:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_Pad_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:61:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:62:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:58:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:60:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:76:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:78:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_FLOAT_32, {.floatValue = 0.000000000000f}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:79:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:81:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:91:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:102:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:89:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:90:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:127:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:138:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)strided_slice_0_ranges,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:125:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:126:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:122:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:124:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:140:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:142:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:143:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:145:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:146:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:148:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:149:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:151:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:161:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:172:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:159:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:160:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:197:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:208:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_Slice_3_ranges,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:195:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:196:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:192:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:194:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:210:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:212:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:213:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:215:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:216:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:218:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:219:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:221:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:231:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:242:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:229:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:230:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:267:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:278:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_Slice_4_ranges,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:265:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:266:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:262:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:264:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:280:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:282:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:283:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:285:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:286:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:288:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:289:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:291:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:301:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:312:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:299:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:300:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:338:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:349:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:336:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:337:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:374:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:385:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_Slice_5_ranges,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:372:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:373:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:369:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:371:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:387:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:389:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:390:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:392:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:393:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:395:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:396:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:398:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:408:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:419:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:406:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:407:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:444:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:455:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_Slice_6_ranges,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:442:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:443:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:439:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:441:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:457:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:459:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:460:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:462:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:463:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:465:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:466:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:468:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 0}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:478:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:489:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:476:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:477:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:515:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:526:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:513:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:514:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:546:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:557:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(_enhance_net_iems_0_cell_act_LeakyRelu_coeff),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:544:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:545:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:571:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:582:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:569:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:570:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:602:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:613:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(enhance_net_iems_0_cell_c1_r_op_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:600:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:601:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:621:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:632:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(enhance_net_iems_0_cell_c1_r_op_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:619:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:620:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:649:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:660:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_cell_c1_r_op_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:647:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:648:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:644:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:646:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:667:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:678:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_cell_c1_r_op_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:665:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:666:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:662:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:664:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:685:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:696:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_0_cell_c1_r_op_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:683:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:684:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:680:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:682:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:698:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:700:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:712:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:723:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:710:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:711:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:749:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:760:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:747:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:748:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:786:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:797:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:784:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:785:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:817:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:828:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(_enhance_net_iems_0_cell_act_1_LeakyRelu_coeff),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:815:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:816:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:842:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# ...
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:3986:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4018:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4029:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(_enhance_net_iems_1_cell_act_6_LeakyRelu_coeff),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4016:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4017:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4043:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4054:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4041:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4042:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4072:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4074:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 3}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4087:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4098:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4085:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4086:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4118:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4129:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(enhance_net_iems_1_cell_c5_weight),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4116:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4117:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4137:38: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                      .id=0,
#                                      ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4148:38: note: first non-designated initializer is here
#                                      {.clientBuf= { .data=BINVARSTART(enhance_net_iems_1_cell_c5_bias),
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4135:36: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                    .version= QNN_TENSOR_VERSION_1,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4136:36: note: first non-designated initializer is here
#                                    {.v1= {
#                                    ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/ruas_w8a8.cpp:4165:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4176:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_1_cell_c5_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4163:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4164:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4160:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4162:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4183:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4194:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_1_cell_c5_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4181:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4182:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4178:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4180:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4201:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4212:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__enhance_net_iems_1_cell_c5_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4199:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4200:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4196:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4198:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4214:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4216:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4228:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4239:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4226:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4227:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4264:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4275:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4262:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4263:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4293:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4295:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_FLOAT_32, {.floatValue = 1.000000000000f}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4296:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4298:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_FLOAT_32, {.floatValue = 0.001000000047f}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4308:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4319:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4306:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4307:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4345:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/ruas_w8a8.cpp:4356:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4343:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4344:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/ruas_w8a8.cpp:4374:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4376:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_FLOAT_32, {.floatValue = 1.000000000000f}}}},
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/ruas_w8a8.cpp:4377:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Inferencing the Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/bin" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/lib" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/dsp/lib"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/$ONDEVICE_FOLDER"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/$QNN_TARGET_STL /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/bin/$QNN_TARGET_ARCH/qnn-net-run /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/hexagon-v73/unsigned/*.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/*.so /data/local/tmp/$ONDEVICE_FOLDER

# %%
# %%bash
# #find ./raw -name *.raw > list.txt
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push output/${QUANTIZED_MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push output/${MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push models/model_libs2/aarch64-android/lib${MODEL_NAME}.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $RAW_FILE_FOLDER /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $TARGET_INPUT_LIST /data/local/tmp/$ONDEVICE_FOLDER

# %% [markdown]
# #### Inferencing the Quantized Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="RUAS"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="ruas_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_Quant_DSP
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnHtp.so --input_list list.txt --retrieve_context ${QUANTIZED_MODEL_NAME}.serialized.bin --output_dir $OUTPUT_FOLDER

# %% [markdown]
# #### Inferencing the 32b Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="RUAS"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="ruas_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_CPU
# cd /data/local/tmp/$ONDEVICE_FOLDER  && 
# ./qnn-net-run --backend libQnnCpu.so --input_list list.txt --model lib${QUANTIZED_MODEL_NAME}.so --output_dir $OUTPUT_FOLDER

# %% [markdown]
# #### Pulling the Output

# %%
# %%bash
# rm -rf OUTPUT_Quant_DSP
# # rm -rf OUTPUT_CPU

# %%
# %%bash
#
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_Quant_DSP output/OUTPUT_Quant_DSP
# # $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_CPU output/OUTPUT_CPU

# %% [markdown]
# ### Pos Processing and Calculating PSNR Value

# %%
import math
def compute_psnr(img_pred, img_true, data_range=255., eps=1e-8):
    err = (img_pred - img_true) ** 2 
    err = np.mean(err)
    return 10. * math.log10((data_range ** 2) / (err + eps))

# %%
def evaluate_average_psnr(el_images, hl_images): #(enhanced_light<model o/p>, high_light <groud_truth>)
    psnr = []
    for i in range(len(el_images)):
        el_img = cv2.imread(el_images[i], 1)
        hl_img = cv2.imread(hl_images[i], 1)
        psnr.append(compute_psnr(el_img,hl_img))
    average_psnr = np.mean(np.array(psnr))
    return average_psnr

# %%
def post_process_enhanced(img):
    img = np.fromfile(img, np.float32)
    img = img.reshape((3,640,480)).astype(np.float32)
    img = np.clip(img * 255. , 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img
