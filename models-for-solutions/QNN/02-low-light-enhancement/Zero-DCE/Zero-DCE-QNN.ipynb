# %% [markdown]
# # Setting Up All Artifacts details

# %%
import os
os.environ['QNN_SDK_ROOT']="/local/mnt/workspace/gokul/QNN/2.19.0.240124" #set up your qnn path here.
os.environ['ANDROID_NDK_ROOT']="/local/mnt/workspace/gokul/android-ndk-r25c"
os.environ['FOLDER_WITH_ARTIFACTS']="ZERO_DCE"
os.environ['RAW_FILE_FOLDER']="raw"
os.environ['MODEL_NAME']="zero_dce_fp32"
os.environ['QUANTIZED_MODEL_NAME']="zero_dce_w8a8"
os.environ['MODEL_PATH']="models/zero_dce_fp32"
os.environ['QUANTIZED_MODEL_PATH']="models/zero_dce_w8a8"
os.environ['TARGET_INPUT_LIST']="list.txt"
os.environ['ONDEVICE_FOLDER']="ZERO_DCE"
os.environ['DEVICE_HOST']="localhost"
os.environ['DEVICE_ID']="bc468c1d" #fill your device-id. Use command "adb devices" to get devices names. example :"e18d5d0"
os.environ['QNN_TARGET_ARCH']="aarch64-android"
os.environ['QNN_TARGET_STL']="libQnnHtp.so"

# %%
from PIL import Image
import glob
import os
import cv2
import numpy as np
import torch
import os
import shutil

# %% [markdown]
# # Getting The Model
#
# - **If You Already have the models in the dlc folder no need to run this cell**
# - [ https://github.com/Li-Chongyi/Zero-DCE.git  ](Link of the Actual Model)
# - Zero-Reference Deep Curve Estimation (Zero-DCE)

# %%
# %%bash
# git clone https://github.com/Li-Chongyi/Zero-DCE
# #git reset  --hard 808e70644191a63c936bd4ce73ce3f10fbc02ec8
# cp Zero_DCE.patch Zero-DCE/Zero-DCE_code
# Out:
# fatal: destination path 'Zero-DCE' already exists and is not an empty directory.

# %%
command1="cd Zero-DCE;cd Zero-DCE_code;patch -i Zero_DCE.patch"
os.system(command1)
# Out:
# patching file model.py
# Reversed (or previously applied) patch detected!  Assume -R? [n]
# Apply anyway? [n]
# Skipping patch.
# 1 out of 1 hunk ignored -- saving rejects to file model.py.rej
# 256

# %%
# %%bash
# cp generate_model.py Zero-DCE/Zero-DCE_code/
# cd Zero-DCE/Zero-DCE_code/
# python generate_model.py
# Out:
# ONNX model saved Successfully

# %% [markdown]
# #### Getting the Non Quantized DLC File

# %% [markdown]
# #### Understanding the Architecture of the Model

# %% [markdown]
# #### Getting the data
# Use the dataset of your choice to validate the pre-processing, and post processing steps given in this notebook

# %%
# %%bash
pip install gdown
gdown --no-check-certificate 157bjO1_cFuSd0HWDUuAmcHRJDVyWpOxB
unzip LOLdataset.zip
rm -rf LOLdataset.zip
rm -rf our485
mkdir raw

# %% [markdown]
# ## Preprocessing the data to generate raw file

# %%
def preprocess(ll_img, hl_img):
    ll_img = np.array(ll_img, dtype='float32')
    hl_img = np.array(hl_img, dtype='float32')
    
    ll_img = np.uint8(np.clip(ll_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    hl_img = np.uint8(np.clip(hl_img, 0., 255.))  # this is to simulate matlab's imwrite operation
    
    ll_img = np.uint8(ll_img)
    hl_img = np.uint8(hl_img)
    
    ll_img = convert_image(ll_img, source='array', target='[0, 1]')
    hl_img = convert_image(hl_img, source='array', target='[0, 1]')
    
    return ll_img, hl_img

# %%
def convert_image(img, source, target):
    if source == 'array':
        img = torch.from_numpy(img.transpose((2, 0, 1))).contiguous()#chw
        img = img.to(dtype=torch.float32).div(255) 
    elif source == '[0, 1]':
        img = torch.clamp(img, 0, 1)  # useful to post-process output of models that can overspill
    
    if target == '[0, 1]':
        pass  # already in [0, 1]
    return img

# %%
def post_process(img):
    img = img.detach().cpu().numpy()
    img = np.clip(255. * img, 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %%
def load_dataset(test_images_dir):
    # Input images for the model
    INPUTS_LL = []
    # Post-processed images for visualization
    IMAGES_LL = [] # LL:Low Light
    IMAGES_HL = [] # HL:High Light

    # Load the test images
    count=0
    for img_path in glob.glob(os.path.join(test_images_dir, '*')):
        l_img = cv2.resize(cv2.imread(img_path),[480,640],interpolation=cv2.INTER_CUBIC)
        l_img = cv2.cvtColor(l_img, cv2.COLOR_BGR2RGB)
        
        h_img = cv2.resize(cv2.imread(img_path.replace("low","high")),[480,640],interpolation=cv2.INTER_CUBIC)
        h_img = cv2.cvtColor(h_img, cv2.COLOR_BGR2RGB)
        
        ll_img, hl_img = preprocess(l_img, h_img)#chw

        INPUTS_LL.append(ll_img)#chw
        IMAGES_LL.append(post_process(ll_img))#hwc
        IMAGES_HL.append(post_process(hl_img))#hwc
    return INPUTS_LL, IMAGES_LL, IMAGES_HL

# %% [markdown]
# **Converting the low dataset to raw file format to give it to the model and do the inference**

# %%
os.makedirs('raw', exist_ok=True)

# %%
test_images_dir = "eval15/low"
INPUTS_LL, IMAGES_LL, IMAGES_HL = load_dataset(test_images_dir)
print(len(INPUTS_LL),len(IMAGES_LL),len(IMAGES_HL))
for i, img_ll in enumerate(INPUTS_LL):
    img_ll = img_ll.cpu().detach().numpy()
    img_ll = img_ll.astype(np.float32)
    fid = open("raw/img_"+str(i)+ ".raw", 'wb')
    img_ll.tofile(fid)
    fid.close()
# Out:
# 15 15 15

# %%
total_iter = 15
print("Generating input_list \"small_raw_list.txt\" with {} iterations".format(total_iter))
with open("list.txt",'w') as f:
    for i in range(total_iter):
        f.write("raw/img_{}.raw\n".format(i))
# Out:
# Generating input_list "small_raw_list.txt" with 15 iterations

# %%
def post_process_enhanced(img):
    img = np.fromfile(img, np.float32)
    img = img.reshape((3,640,480)).astype(np.float32)
    img = np.clip(img* 255. , 0., 255.)
    img = np.uint8(img)
    img = img.transpose(1, 2, 0)#hwc
    return img

# %% [markdown]
# #### Getting the Quantized Model

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network zero_dce.onnx --output_path ${MODEL_PATH}.cpp
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${MODEL_PATH}.cpp -b ${MODEL_PATH}.bin -o models/model_libs
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs/x86_64-linux-clang/lib${MODEL_NAME}.so \
#               --binary_file ${MODEL_NAME}.serialized

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network zero_dce.onnx --output_path ${QUANTIZED_MODEL_PATH}.cpp --input_list list.txt \
#                 --param_quantizer "adjusted" --act_quantizer "enhanced"
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${QUANTIZED_MODEL_PATH}.cpp -b ${QUANTIZED_MODEL_PATH}.bin -o models/model_libs2
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs2/x86_64-linux-clang/lib${QUANTIZED_MODEL_NAME}.so \
#               --binary_file ${QUANTIZED_MODEL_NAME}.serialized
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# 2024-03-04 09:50:54,680 - 235 - INFO - Simplified model validation is successful
# 2024-03-04 09:50:55,549 - 235 - INFO - Saving QNN Model...
# IrQuantizer: Quantizer param type: adjusted will be deprecated in future releases
# IrQuantizer: Quantizer type: adjusted is no longer supported. Using TF quantizer instead
# 2024-03-04 09:51:16,228 - 235 - INFO - Model CPP saved at: models/zero_dce_w8a8.cpp
# 2024-03-04 09:51:16,228 - 235 - INFO - Model BIN saved at: /local/mnt/workspace/gokul/models-for-solutions/02-low-light-enhancement/Zero-DCE/models/zero_dce_w8a8.bin
# 2024-03-04 09:51:16,229 - 235 - INFO - Conversion complete!
#      0.1ms [  INFO ] Inferences will run in sync mode
#      0.1ms [  INFO ] Initializing logging in the backend. Callback: [0x7f4dcb842e10], Log Level: [3]
#      0.1ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.1ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.1ms [  INFO ] Entering QuantizeRuntimeApp flow
#     10.7ms [  INFO ] CpuGraph::finalize
#    346.4ms [  INFO ] CpuGraph::execute
#   2140.5ms [  INFO ] cleaning up resources for input tensors
#   2140.6ms [  INFO ] cleaning up resources for output tensors
#   2196.6ms [  INFO ] CpuGraph::execute
#   3522.5ms [  INFO ] cleaning up resources for input tensors
#   3522.5ms [  INFO ] cleaning up resources for output tensors
#   3550.5ms [  INFO ] CpuGraph::execute
#   4823.9ms [  INFO ] cleaning up resources for input tensors
#   4823.9ms [  INFO ] cleaning up resources for output tensors
#   4850.4ms [  INFO ] CpuGraph::execute
#   6130.8ms [  INFO ] cleaning up resources for input tensors
#   6130.8ms [  INFO ] cleaning up resources for output tensors
#   6157.4ms [  INFO ] CpuGraph::execute
#   7418.4ms [  INFO ] cleaning up resources for input tensors
#   7418.4ms [  INFO ] cleaning up resources for output tensors
#   7445.0ms [  INFO ] CpuGraph::execute
#   8685.6ms [  INFO ] cleaning up resources for input tensors
#   8685.6ms [  INFO ] cleaning up resources for output tensors
#   8712.3ms [  INFO ] CpuGraph::execute
#  10057.1ms [  INFO ] cleaning up resources for input tensors
#  10057.2ms [  INFO ] cleaning up resources for output tensors
#  10083.3ms [  INFO ] CpuGraph::execute
#  11341.7ms [  INFO ] cleaning up resources for input tensors
#  11341.7ms [  INFO ] cleaning up resources for output tensors
#  11368.6ms [  INFO ] CpuGraph::execute
#  12606.3ms [  INFO ] cleaning up resources for input tensors
#  12606.3ms [  INFO ] cleaning up resources for output tensors
#  12632.8ms [  INFO ] CpuGraph::execute
#  13885.7ms [  INFO ] cleaning up resources for input tensors
#  13885.7ms [  INFO ] cleaning up resources for output tensors
#  13912.5ms [  INFO ] CpuGraph::execute
#  15281.4ms [  INFO ] cleaning up resources for input tensors
#  15281.5ms [  INFO ] cleaning up resources for output tensors
#  15308.2ms [  INFO ] CpuGraph::execute
#  16657.0ms [  INFO ] cleaning up resources for input tensors
#  16657.0ms [  INFO ] cleaning up resources for output tensors
#  16683.9ms [  INFO ] CpuGraph::execute
#  17932.4ms [  INFO ] cleaning up resources for input tensors
#  17932.4ms [  INFO ] cleaning up resources for output tensors
#  17958.8ms [  INFO ] CpuGraph::execute
#  19224.7ms [  INFO ] cleaning up resources for input tensors
#  19224.7ms [  INFO ] cleaning up resources for output tensors
#  19253.6ms [  INFO ] CpuGraph::execute
#  20573.6ms [  INFO ] cleaning up resources for input tensors
#  20573.6ms [  INFO ] cleaning up resources for output tensors
#  20633.3ms [  INFO ] Freeing graphsInfo
#
# --------------------------
# INFO: Building for target: x86_64-linux-clang
# --------------------------
# mkdir -p obj/x86_64-linux-clang
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModel.cpp -o obj/x86_64-linux-clang/QnnModel.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModelPal.cpp -o obj/x86_64-linux-clang/QnnModelPal.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnWrapperUtils.cpp -o obj/x86_64-linux-clang/QnnWrapperUtils.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/zero_dce_w8a8.cpp -o obj/x86_64-linux-clang/zero_dce_w8a8.o
# mkdir -p obj/binary/x86_64-linux-clang
# touch obj/binary/extractbinary
# mkdir -p libs/x86_64-linux-clang
#
# --------------------------
# INFO: Building for target: aarch64-android
# --------------------------
# Android NDK: android-16 is unsupported. Using minimum supported version android-19.
# Android NDK: WARNING: Unsupported source file extensions in jni/Android.mk for module zero_dce_w8a8
# Android NDK:   /_Constant_output_0.o /e_conv1_bias.o /e_conv1_weight.o /e_conv2_bias.o /e_conv2_weight.o /e_conv3_bias.o /e_conv3_weight.o /e_conv4_bias.o /e_conv4_weight.o /e_conv5_bias.o /e_conv5_weight.o /e_conv6_bias.o /e_conv6_weight.o /e_conv7_bias.o /e_conv7_weight.o
# [arm64-v8a] Compile++      : zero_dce_w8a8 <= QnnModel.cpp
# [arm64-v8a] Compile++      : zero_dce_w8a8 <= QnnModelPal.cpp
# [arm64-v8a] Compile++      : zero_dce_w8a8 <= QnnWrapperUtils.cpp
# [arm64-v8a] Compile++      : zero_dce_w8a8 <= zero_dce_w8a8.cpp
# jni/zero_dce_w8a8.cpp:39:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:50:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=nullptr,
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:37:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:38:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:58:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:69:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv1_weight),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:56:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:57:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:77:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:88:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv1_bias),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:75:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:76:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:105:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:116:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv1_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:103:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:104:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:100:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:102:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:123:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:134:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv1_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:121:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:122:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:118:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:120:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:141:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:152:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv1_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:139:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:140:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:136:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:138:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:154:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:156:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:168:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:179:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:166:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:167:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:199:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:210:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv2_weight),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:197:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:198:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:218:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:229:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv2_bias),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:216:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:217:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:246:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:257:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:244:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:245:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:241:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:243:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:264:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:275:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:262:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:263:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:259:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:261:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:282:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:293:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:280:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:281:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:277:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:279:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:295:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:297:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:309:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:320:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:307:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:308:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:340:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:351:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv3_weight),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:338:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:339:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:359:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:370:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv3_bias),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:357:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:358:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:387:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:398:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv3_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:385:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:386:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:382:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:384:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:405:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:416:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv3_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:403:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:404:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:400:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:402:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:423:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:434:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv3_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:421:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:422:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:418:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:420:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:436:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:438:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:450:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:461:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:448:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:449:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:481:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:492:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv4_weight),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:479:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:480:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:500:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:511:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv4_bias),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:498:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:499:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:528:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:539:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv4_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:526:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:527:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:523:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:525:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:546:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:557:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv4_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:544:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:545:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:541:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:543:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:564:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:575:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv4_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:562:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:563:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:559:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:561:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:577:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:579:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:591:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:602:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:589:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:590:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:620:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:622:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 3}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:633:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:644:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:631:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:632:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:664:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:675:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv5_weight),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:662:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:663:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:683:42: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                          .id=0,
#                                          ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:694:42: note: first non-designated initializer is here
#                                          {.clientBuf= { .data=BINVARSTART(e_conv5_bias),
#                                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:681:40: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                        .version= QNN_TENSOR_VERSION_1,
#                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:682:40: note: first non-designated initializer is here
#                                        {.v1= {
#                                        ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/zero_dce_w8a8.cpp:711:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:722:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv5_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:709:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:710:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:706:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:708:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:729:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:740:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv5_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:727:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:728:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:724:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:726:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:747:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:758:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__e_conv5_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:745:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:746:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:742:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ...
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2003:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2041:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2052:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2039:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2040:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2078:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2089:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2076:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2077:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2115:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2126:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2113:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2114:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2152:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2163:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2150:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2151:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2189:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2200:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2187:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2188:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2226:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2237:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2224:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2225:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2263:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2274:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2261:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2262:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2300:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2311:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2298:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2299:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2337:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2348:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2335:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2336:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2374:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2385:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2372:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2373:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2411:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2422:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2409:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2410:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2448:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2459:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2446:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2447:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2485:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2496:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2483:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2484:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2522:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2533:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2520:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2521:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2559:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2570:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2557:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2558:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/zero_dce_w8a8.cpp:2588:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2590:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 3}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2607:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/zero_dce_w8a8.cpp:2618:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2605:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/zero_dce_w8a8.cpp:2606:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# 214 warnings generated.
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/_Constant_output_0.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//_Constant_output_0.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv1_bias.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv1_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv1_weight.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv1_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv2_bias.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv2_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv2_weight.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv2_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv3_bias.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv3_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv3_weight.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv3_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv4_bias.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv4_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv4_weight.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv4_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv5_bias.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv5_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv5_weight.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv5_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv6_bias.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv6_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv6_weight.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv6_weight.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv7_bias.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv7_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/e_conv7_weight.raw obj/local/arm64-v8a/objs/zero_dce_w8a8//e_conv7_weight.o
# [arm64-v8a] SharedLibrary  : libzero_dce_w8a8.so
# [arm64-v8a] Install        : libzero_dce_w8a8.so => libs/arm64-v8a/libzero_dce_w8a8.so
# INFO: Output libraries saved at /local/mnt/workspace/gokul/models-for-solutions/02-low-light-enhancement/Zero-DCE/models/model_libs2
# INFO: Building models/zero_dce_w8a8.cpp complete.
# qnn-context-binary-generator pid:231665

# %% [markdown]
# ## Inferencing the Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/bin" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/lib" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/dsp/lib"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/$ONDEVICE_FOLDER"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/$QNN_TARGET_STL /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/bin/$QNN_TARGET_ARCH/qnn-net-run /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/hexagon-v73/unsigned/*.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/*.so /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtp.so: 1 file pushed, 0 skipped. 418.2 MB/s (1545520 bytes in 0.004s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/bin/aarch64-android/qnn-net-run: 1 file pushed, 0 skipped. 416.9 MB/s (1441208 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libCalculator_skel.so: 1 file pushed, 0 skipped. 131.8 MB/s (7128 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73QemuDriver.so: 1 file pushed, 0 skipped. 494.1 MB/s (7601584 bytes in 0.015s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73Skel.so: 1 file pushed, 0 skipped. 511.2 MB/s (7360784 bytes in 0.014s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnHtpV73.so: 1 file pushed, 0 skipped. 507.2 MB/s (8025008 bytes in 0.015s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSaver.so: 1 file pushed, 0 skipped. 386.7 MB/s (280044 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/hexagon-v73/unsigned/libQnnSystem.so: 1 file pushed, 0 skipped. 955.6 MB/s (56360 bytes in 0.000s)
# 6 files pushed, 0 skipped. 212.6 MB/s (23330908 bytes in 0.105s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libhta_hexagon_runtime_qnn.so: 1 file pushed, 0 skipped. 438.5 MB/s (2789832 bytes in 0.006s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnChrometraceProfilingReader.so: 1 file pushed, 0 skipped. 417.5 MB/s (516568 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnCpu.so: 1 file pushed, 0 skipped. 527.7 MB/s (4822376 bytes in 0.009s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspNetRunExtensions.so: 1 file pushed, 0 skipped. 496.0 MB/s (634024 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDsp.so: 1 file pushed, 0 skipped. 444.6 MB/s (1238520 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66CalculatorStub.so: 1 file pushed, 0 skipped. 410.7 MB/s (6368 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnDspV66Stub.so: 1 file pushed, 0 skipped. 459.6 MB/s (278216 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuNetRunExtensions.so: 1 file pushed, 0 skipped. 477.6 MB/s (626472 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpuProfilingReader.so: 1 file pushed, 0 skipped. 488.9 MB/s (517864 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnGpu.so: 1 file pushed, 0 skipped. 517.7 MB/s (4484984 bytes in 0.008s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtaNetRunExtensions.so: 1 file pushed, 0 skipped. 482.4 MB/s (621800 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHta.so: 1 file pushed, 0 skipped. 457.6 MB/s (896360 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpNetRunExtensions.so: 1 file pushed, 0 skipped. 464.7 MB/s (721360 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpOptraceProfilingReader.so: 1 file pushed, 0 skipped. 482.1 MB/s (617896 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpPrepare.so: 1 file pushed, 0 skipped. 400.5 MB/s (26627504 bytes in 0.063s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpProfilingReader.so: 1 file pushed, 0 skipped. 488.6 MB/s (502584 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtp.so: 1 file pushed, 0 skipped. 474.8 MB/s (1545520 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV68CalculatorStub.so: 1 file pushed, 0 skipped. 337.2 MB/s (6416 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV68Stub.so: 1 file pushed, 0 skipped. 462.2 MB/s (281936 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV69CalculatorStub.so: 1 file pushed, 0 skipped. 508.9 MB/s (6416 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV69Stub.so: 1 file pushed, 0 skipped. 462.5 MB/s (282816 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV73CalculatorStub.so: 1 file pushed, 0 skipped. 576.2 MB/s (6968 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV73Stub.so: 1 file pushed, 0 skipped. 459.8 MB/s (290408 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV75CalculatorStub.so: 1 file pushed, 0 skipped. 444.8 MB/s (6968 bytes in 0.000s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnHtpV75Stub.so: 1 file pushed, 0 skipped. 469.3 MB/s (290408 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnJsonProfilingReader.so: 1 file pushed, 0 skipped. 500.1 MB/s (521504 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnModelDlc.so: 1 file pushed, 0 skipped. 481.9 MB/s (1598240 bytes in 0.003s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSaver.so: 1 file pushed, 0 skipped. 472.7 MB/s (689360 bytes in 0.001s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSystem.so: 1 file pushed, 0 skipped. 428.7 MB/s (229024 bytes in 0.001s)
# 29 files pushed, 0 skipped. 297.8 MB/s (51658712 bytes in 0.165s)

# %%
# %%bash
# #find ./raw -name *.raw > list.txt
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push output/${QUANTIZED_MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push output/${MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push models/model_libs2/aarch64-android/lib${QUANTIZED_MODEL_NAME}.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $RAW_FILE_FOLDER /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $TARGET_INPUT_LIST /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# output/zero_dce_w8a8.serialized.bin: 1 file pushed, 0 skipped. 348.6 MB/s (695088 bytes in 0.002s)
# adb: error: cannot stat 'output/zero_dce_fp32.serialized.bin': No such file or directory
# models/model_libs2/aarch64-android/libzero_dce_w8a8.so: 1 file pushed, 0 skipped. 324.3 MB/s (436200 bytes in 0.001s)
# raw/: 15 files pushed, 0 skipped. 316.7 MB/s (55296000 bytes in 0.166s)
# list.txt: 1 file pushed, 0 skipped. 4.5 MB/s (215 bytes in 0.000s)

# %% [markdown]
# #### Inferencing the Quantized Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="ZERO_DCE"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="zero_dce_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_Quant_DSP
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnHtp.so --input_list list.txt --retrieve_context ${QUANTIZED_MODEL_NAME}.serialized.bin --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:13197
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/ZERO_DCE" (ignoring)
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/ZERO_DCE" (ignoring)

# %% [markdown]
# #### Inferencing the Non-Quantized Model

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="ZERO_DCE"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="zero_dce_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_CPU
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnCpu.so --input_list list.txt --model lib${QUANTIZED_MODEL_NAME}.so --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:13205

# %% [markdown]
# #### Pulling the Output

# %%
# %%bash
# rm -rf OUTPUT_Quant_DSP
# rm -rf OUTPUT_CPU

# %%
# %%bash
#
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_Quant_DSP output/OUTPUT_Quant_DSP
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_CPU output/OUTPUT_CPU
# Out:
# /data/local/tmp/ZERO_DCE/OUTPUT_Quant_DSP/: 45 files pulled, 0 skipped. 143.2 MB/s (552960000 bytes in 3.683s)
# /data/local/tmp/ZERO_DCE/OUTPUT_CPU/: 45 files pulled, 0 skipped. 149.4 MB/s (552960000 bytes in 3.529s)

# %% [markdown]
# ### Post Processing and Calculating PSNR Value

# %%
import math
def compute_psnr(img_pred, img_true, data_range=255., eps=1e-8):
    err = (img_pred - img_true) ** 2 
    err = np.mean(err)
    return 10. * math.log10((data_range ** 2) / (err + eps))

# %%
def evaluate_average_psnr(el_images, hl_images): #(enhanced_light<model o/p>, high_light <groud_truth>)
    psnr = []
    for i in range(len(el_images)):
        el_img = cv2.imread(el_images[i], 1)
        hl_img = cv2.imread(hl_images[i], 1)
        psnr.append(compute_psnr(el_img,hl_img))
    average_psnr = np.mean(np.array(psnr))
    return average_psnr
