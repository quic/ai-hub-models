# %% [markdown]
# ## Setting UP SNPE Artifacts

# %%
import os
os.environ['QNN_SDK_ROOT']="/local/mnt/workspace/gokul/QNN/2.19.0.240124" #set up your qnn path here.
os.environ['ANDROID_NDK_ROOT']="/local/mnt/workspace/gokul/android-ndk-r25c"
os.environ['RAW_FILE_FOLDER']="input/raw"
os.environ['MODEL_NAME']="deeplabv3_resnet101_fp32"
os.environ['QUANTIZED_MODEL_NAME']="deeplabv3_resnet101_quant_w8a8"
os.environ['MODEL_PATH']="models/deeplabv3_resnet101_fp32"
os.environ['QUANTIZED_MODEL_PATH']="models/deeplabv3_resnet101_quant_w8a8"
os.environ['TARGET_INPUT_LIST']="input/input.txt"
os.environ['ONDEVICE_FOLDER']="deeplabv3_resnet101"
os.environ['DEVICE_HOST']="localhost"
os.environ['DEVICE_ID']="bc468c1d" #fill your device-id. Use command "adb devices" to get devices names. example :"e18d5d0"
os.environ['QNN_TARGET_ARCH']="aarch64-android"
os.environ['QNN_TARGET_STL']="libQnnHtp.so"

# %%
import os
import torchvision.models.segmentation as models
import torch
import torch.nn as nn

# %%
pretrained_model = models.deeplabv3_resnet101(pretrained=True)
pretrained_model.eval()
class CustomModel(nn.Module):
    def __init__(self,pretrained_model):
        super(CustomModel,self).__init__()
        self.pretrained_model = pretrained_model
        self.argmax = nn.LogSoftmax(dim=1)

    def forward(self,x):
        output_dict = self.pretrained_model(x)
        output = output_dict['out']
        argmax_output = torch.argmax(output,dim=1,keepdim=False)
        return argmax_output

model = CustomModel(pretrained_model)
input = torch.randn(1,3,400,400)
output = model(input)
output.shape
# Out:
# /local/mnt/workspace/gokul/gokul-env/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /local/mnt/workspace/gokul/gokul-env/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet101_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# torch.Size([1, 400, 400])

# %%
os.makedirs('models',exist_ok=True)

# %%
import os
dummy_input = torch.randn(1,3, 400, 400).type(torch.FloatTensor).to('cpu')
torch.onnx.export(model, dummy_input, "./models/deeplabv3_resnet101.onnx",opset_version=11)

# %%
import os
import cv2
import glob
import numpy as np
import torch
from os.path import isfile, join
import matplotlib.pyplot as plt 
from PIL import Image
from torchvision import transforms as T

# %%
os.makedirs('input',exist_ok=True)
os.makedirs('input/dataset',exist_ok=True)

# %% [markdown]
# ## Download dataset in input/dataset/ directory

# %%
from tqdm import tqdm
import requests
url = 'http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar'
response = requests.get(url,stream=True)
size = int(response.headers.get('content-length',0))
with open('input/dataset/VOCtrainval_11-May-2012.tar','wb') as file:
    for data in tqdm(response.iter_content(chunk_size=1024), total=size, unit='B', unit_scale=True):
        file.write(data)

# %%
from tqdm import tqdm
import tarfile
# Define the path to the large file
file_path = "input/dataset/VOCtrainval_11-May-2012.tar"
with tarfile.open(file_path, "r:tar") as tar:
    file_size = sum([member.size for member in tar.getmembers()])
    progress_bar = tqdm(total=file_size, unit="B", unit_scale=True)
    for member in tar.getmembers():
        tar.extract(member)
        progress_bar.update(member.size)
    progress_bar.close()

# %%
# %%bash
# cp -r VOCdevkit/ input/dataset/
# rm -rf VOCdevkit/

# %%
def preProcess(file):
    img = Image.open(file).convert('RGB')
    img = transform(img).unsqueeze(0) # To tensor of NCHW
    # print(img.shape)
    img = np.transpose(img, (0,2,3,1))
    #print(img.shape) 
    img = img.numpy()
    print(img.shape)
    return img

# %%
os.makedirs('input/raw',exist_ok=True)

# %%
test_images_dir = "input/dataset/VOCdevkit/VOC2012/JPEGImages/"
image_count=10
crop_size=400
transform = T.Compose([
                T.Resize((crop_size,crop_size)),
                
                T.ToTensor(),
                T.Normalize(mean=[0.485, 0.456, 0.406],
                                std=[0.229, 0.224, 0.225]),
            ])

image_paths = []
c=0
inputlist = open('input/dataset/VOCdevkit/VOC2012/ImageSets/Segmentation/val.txt', 'r')
Lines = inputlist.readlines()
Lines = [line.strip() + ".jpg" for line in Lines]
for line in Lines:
    image_paths.extend(glob.glob(os.path.join(test_images_dir, line)))
    c = c+1
    if(c==image_count):
        break
image_paths = sorted(image_paths)
count=0
for img_path in image_paths:
    print("img_path: ", img_path)
    img = preProcess(img_path)
    name = img_path.replace(test_images_dir,"")
    name = name.split('.')[0]
    #print(name)
    raw_data = os.path.join('input/raw/preproc_'+name+'.raw')
    img.tofile(raw_data)
    count = count+1
    if count==image_count:
        break
    print("raw image saved")

# %%
directory_path = 'input/raw/'
output_file_path = 'input/input.txt'  # The file where the output will be saved
all_files = os.listdir(directory_path)
# Filter only the .raw files and create a list of their names
raw_files = [file for file in all_files if file.endswith('.raw')]
raw_files = sorted(raw_files)
# Write the file names to the output file
with open(output_file_path, 'w') as f:
    c=0
    for raw_file in raw_files:
        f.write(f"./raw/{raw_file}\n")
        c=c+1
print(f"File names written to {output_file_path}.")
# Out:
# File names written to input/input.txt.

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network models/deeplabv3_resnet101.onnx --output_path ${MODEL_PATH}.cpp
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${MODEL_PATH}.cpp -b ${MODEL_PATH}.bin -o models/model_libs
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs/x86_64-linux-clang/lib${MODEL_NAME}.so \
#               --binary_file ${MODEL_NAME}.serialized

# %%
# %%bash
# source ${QNN_SDK_ROOT}/bin/envsetup.sh
# export PATH=${ANDROID_NDK_ROOT}:${PATH}
# cd input
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-onnx-converter --input_network ../models/deeplabv3_resnet101.onnx --output_path ../${QUANTIZED_MODEL_PATH}.cpp --input_list input.txt \
#                 --param_quantizer "adjusted" --act_quantizer "enhanced"
# cd ..
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-model-lib-generator -c ${QUANTIZED_MODEL_PATH}.cpp -b ${QUANTIZED_MODEL_PATH}.bin -o models/model_libs2
# ${QNN_SDK_ROOT}/bin/x86_64-linux-clang/qnn-context-binary-generator \
#               --backend ${QNN_SDK_ROOT}/lib/x86_64-linux-clang/libQnnHtp.so \
#               --model models/model_libs2/x86_64-linux-clang/lib${QUANTIZED_MODEL_NAME}.so \
#               --binary_file ${QUANTIZED_MODEL_NAME}.serialized \
#               --config_file htp_vtcm_config.json
# Out:
# [INFO] AISW SDK environment set
# [INFO] QNN_SDK_ROOT: /local/mnt/workspace/gokul/QNN/2.19.0.240124
# 2024-03-04 14:33:48,851 - 235 - INFO - Simplified model validation is successful
# 2024-03-04 14:33:53,001 - 235 - INFO - Saving QNN Model...
# IrQuantizer: Quantizer param type: adjusted will be deprecated in future releases
# IrQuantizer: Quantizer type: adjusted is no longer supported. Using TF quantizer instead
# 2024-03-04 14:33:57,437 - 235 - INFO - Model CPP saved at: ../models/deeplabv3_resnet101_quant_w8a8.cpp
# 2024-03-04 14:33:57,440 - 235 - INFO - Model BIN saved at: /local/mnt/workspace/gokul/models-for-solutions/04-image-segmentation/deeplabv3_resnet101/models/deeplabv3_resnet101_quant_w8a8.bin
# 2024-03-04 14:33:57,444 - 235 - INFO - Conversion complete!
#      0.1ms [  INFO ] Inferences will run in sync mode
#      0.2ms [  INFO ] Initializing logging in the backend. Callback: [0x7f55c3040e10], Log Level: [3]
#      0.2ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.3ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.3ms [  INFO ] Entering QuantizeRuntimeApp flow
#    111.7ms [  INFO ] CpuGraph::finalize
#    370.4ms [  INFO ] CpuGraph::execute
#   3604.0ms [  INFO ] cleaning up resources for input tensors
#   3604.0ms [  INFO ] cleaning up resources for output tensors
#   3926.4ms [  INFO ] Freeing graphsInfo
#
# --------------------------
# INFO: Building for target: x86_64-linux-clang
# --------------------------
# mkdir -p obj/x86_64-linux-clang
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/deeplabv3_resnet101_quant_w8a8.cpp -o obj/x86_64-linux-clang/deeplabv3_resnet101_quant_w8a8.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModel.cpp -o obj/x86_64-linux-clang/QnnModel.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnModelPal.cpp -o obj/x86_64-linux-clang/QnnModelPal.o
# clang++-9 -c -std=c++11 -march=x86-64 -O3 -fno-exceptions -fno-rtti -Wno-write-strings -DQNN_API="__attribute__((visibility(\"default\")))" -fPIC -fvisibility=hidden -Ijni/ -I/local/mnt/workspace/gokul/QNN/2.19.0.240124/include/QNN jni/QnnWrapperUtils.cpp -o obj/x86_64-linux-clang/QnnWrapperUtils.o
# mkdir -p obj/binary/x86_64-linux-clang
# touch obj/binary/extractbinary
# mkdir -p libs/x86_64-linux-clang
#
# --------------------------
# INFO: Building for target: aarch64-android
# --------------------------
# Android NDK: android-16 is unsupported. Using minimum supported version android-19.
# Android NDK: WARNING: Unsupported source file extensions in jni/Android.mk for module deeplabv3_resnet101_quant_w8a8
# Android NDK:   /onnx__Conv_1075.o /onnx__Conv_1076.o /onnx__Conv_1078.o /onnx__Conv_1079.o /onnx__Conv_1081.o /onnx__Conv_1082.o /onnx__Conv_1084.o /onnx__Conv_1085.o /onnx__Conv_1087.o /onnx__Conv_1088.o /onnx__Conv_1090.o /onnx__Conv_1091.o /onnx__Conv_1093.o /onnx__Conv_1094.o /onnx__Conv_1096.o /onnx__Conv_1097.o /onnx__Conv_1099.o /onnx__Conv_1100.o /onnx__Conv_1102.o /onnx__Conv_1103.o /onnx__Conv_1105.o /onnx__Conv_1106.o /onnx__Conv_1108.o /onnx__Conv_1109.o /onnx__Conv_1111.o /onnx
13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_maxpool_MaxPool_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:224:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:225:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:221:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:223:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:244:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:255:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_maxpool_MaxPool_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:242:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:243:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:239:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:241:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:266:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:277:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:264:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:265:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:297:59: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                           .id=0,
#                                                           ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:308:59: note: first non-designated initializer is here
#                                                           {.clientBuf= { .data=BINVARSTART(onnx__Conv_1078),
#                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:295:57: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                         .version= QNN_TENSOR_VERSION_1,
#                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:296:57: note: first non-designated initializer is here
#                                                         {.v1= {
#                                                         ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:316:59: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                           .id=0,
#                                                           ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:327:59: note: first non-designated initializer is here
#                                                           {.clientBuf= { .data=BINVARSTART(onnx__Conv_1079),
#                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:314:57: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                         .version= QNN_TENSOR_VERSION_1,
#                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:315:57: note: first non-designated initializer is here
#                                                         {.v1= {
#                                                         ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:344:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:355:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv1_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:342:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:343:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:339:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:341:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:362:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:373:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv1_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:360:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:361:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:357:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:359:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:380:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:391:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv1_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:378:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:379:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:375:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:377:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:393:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:395:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:407:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:418:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:405:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:406:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:438:59: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                           .id=0,
#                                                           ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:449:59: note: first non-designated initializer is here
#                                                           {.clientBuf= { .data=BINVARSTART(onnx__Conv_1081),
#                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:436:57: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                         .version= QNN_TENSOR_VERSION_1,
#                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:437:57: note: first non-designated initializer is here
#                                                         {.v1= {
#                                                         ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:457:59: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                           .id=0,
#                                                           ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:468:59: note: first non-designated initializer is here
#                                                           {.clientBuf= { .data=BINVARSTART(onnx__Conv_1082),
#                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:455:57: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                         .version= QNN_TENSOR_VERSION_1,
#                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:456:57: note: first non-designated initializer is here
#                                                         {.v1= {
#                                                         ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:485:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:496:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv2_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:483:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:484:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:480:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:482:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:503:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:514:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv2_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:501:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:502:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:498:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:500:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:521:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:532:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv2_Conv_stride,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:519:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:520:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:516:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:518:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:534:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_SCALAR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:536:6: note: first non-designated initializer is here
#      {.scalarParam= (Qnn_Scalar_t) {QNN_DATATYPE_UINT_32, {.uint32Value = 1}}}}
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:548:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:559:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=nullptr,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:546:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:547:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:579:59: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                           .id=0,
#                                                           ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:590:59: note: first non-designated initializer is here
#                                                           {.clientBuf= { .data=BINVARSTART(onnx__Conv_1084),
#                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:577:57: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                         .version= QNN_TENSOR_VERSION_1,
#                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:578:57: note: first non-designated initializer is here
#                                                         {.v1= {
#                                                         ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:598:59: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                           .id=0,
#                                                           ^~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:609:59: note: first non-designated initializer is here
#                                                           {.clientBuf= { .data=BINVARSTART(onnx__Conv_1085),
#                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:596:57: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#                                                         .version= QNN_TENSOR_VERSION_1,
#                                                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:597:57: note: first non-designated initializer is here
#                                                         {.v1= {
#                                                         ^~~~~~~
# jni/QnnWrapperUtils.hpp:77:17: note: expanded from macro 'VALIDATE'
#     retStatus = value;                                                                           \
#                 ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:626:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:637:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv3_Conv_dilation,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:624:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:625:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:621:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:623:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:644:13: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#             .id=0,
#             ^~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:655:13: note: first non-designated initializer is here
#             {.clientBuf= { .data=(uint8_t*)__pretrained_model_backbone_layer1_layer1_0_conv3_Conv_pad_amount,
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:642:11: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#           .version= QNN_TENSOR_VERSION_1,
#           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:643:11: note: first non-designated initializer is here
#           {.v1= {
#           ^~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:639:6: warning: mixture of designated and non-designated initializers in the same initializer list is a C99 extension [-Wc99-designator]
#     {.paramType=QNN_PARAMTYPE_TENSOR,
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# jni/deeplabv3_resnet101_quant_w8a8.cpp:641:6: note: first non-designated initializer is here
#      {.tensorParam=(Qnn_Tensor_t) {
#      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ...
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1318.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1318.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1319.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1319.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1321.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1321.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1322.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1322.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1324.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1324.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1325.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1325.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1327.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1327.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1328.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1328.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1330.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1330.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1331.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1331.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1333.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1333.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1334.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1334.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1336.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1336.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1337.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1337.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1339.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1339.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1340.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1340.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1342.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1342.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1343.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1343.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1345.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1345.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1346.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1346.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1348.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1348.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1349.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1349.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1351.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1351.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1352.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1352.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1354.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1354.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1355.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1355.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1357.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1357.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1358.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1358.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1360.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1360.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1361.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1361.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1363.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1363.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1364.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1364.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1366.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1366.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1367.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1367.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1369.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1369.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1370.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1370.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1372.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1372.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1373.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1373.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1375.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1375.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1376.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1376.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1378.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1378.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1379.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1379.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1381.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1381.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1382.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1382.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1384.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1384.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1385.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1385.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1387.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1387.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1388.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1388.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1390.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1390.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1391.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1391.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1393.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1393.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1394.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1394.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1396.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1396.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1397.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1397.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1399.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1399.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1400.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1400.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1402.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1402.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1403.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1403.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1405.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1405.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/onnx__Conv_1406.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//onnx__Conv_1406.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/pretrained_model_classifier_4_bias.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//pretrained_model_classifier_4_bias.o
# /local/mnt/workspace/gokul/android-ndk-r25c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-objcopy -I binary -O elf64-littleaarch64 -B aarch64 obj/binary/pretrained_model_classifier_4_weight.raw obj/local/arm64-v8a/objs/deeplabv3_resnet101_quant_w8a8//pretrained_model_classifier_4_weight.o
# [arm64-v8a] SharedLibrary  : libdeeplabv3_resnet101_quant_w8a8.so
# [arm64-v8a] Install        : libdeeplabv3_resnet101_quant_w8a8.so => libs/arm64-v8a/libdeeplabv3_resnet101_quant_w8a8.so
# INFO: Output libraries saved at /local/mnt/workspace/gokul/models-for-solutions/04-image-segmentation/deeplabv3_resnet101/models/model_libs2
# INFO: Building models/deeplabv3_resnet101_quant_w8a8.cpp complete.
# qnn-context-binary-generator pid:1056032

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/bin" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/$QNN_TARGET_ARCH/lib" && $DEVICE_SHELL shell "mkdir -p /data/local/tmp/qnnexample/dsp/lib"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell "mkdir -p /data/local/tmp/$ONDEVICE_FOLDER"

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/$QNN_TARGET_STL /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/bin/$QNN_TARGET_ARCH/qnn-net-run /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/hexagon-v73/unsigned/*.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $QNN_SDK_ROOT/lib/$QNN_TARGET_ARCH/*.so /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnH
)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnModelDlc.so: 1 file pushed, 0 skipped. 375.9 MB/s (1598240 bytes in 0.004s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSaver.so: 1 file pushed, 0 skipped. 424.8 MB/s (689360 bytes in 0.002s)
# /local/mnt/workspace/gokul/QNN/2.19.0.240124/lib/aarch64-android/libQnnSystem.so: 1 file pushed, 0 skipped. 421.1 MB/s (229024 bytes in 0.001s)
# 29 files pushed, 0 skipped. 313.1 MB/s (51658712 bytes in 0.157s)

# %%
# %%bash
# #find ./raw -name *.raw > list.txt
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL push output/${QUANTIZED_MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push output/${MODEL_NAME}.serialized.bin /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push models/model_libs2/aarch64-android/lib${QUANTIZED_MODEL_NAME}.so /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $RAW_FILE_FOLDER /data/local/tmp/$ONDEVICE_FOLDER
# $DEVICE_SHELL push $TARGET_INPUT_LIST /data/local/tmp/$ONDEVICE_FOLDER
# Out:
# output/deeplabv3_resnet101_quant_w8a8.serialized.bin: 1 file pushed, 0 skipped. 330.5 MB/s (60797048 bytes in 0.175s)
# output/deeplabv3_resnet101_fp32.serialized.bin: 1 file pushed, 0 skipped. 190.0 MB/s (234782808 bytes in 1.178s)
# models/model_libs2/aarch64-android/libdeeplabv3_resnet101_quant_w8a8.so: 1 file pushed, 0 skipped. 322.1 MB/s (59349288 bytes in 0.176s)
# input/raw/: 1 file pushed, 0 skipped. 84.8 MB/s (1920000 bytes in 0.022s)
# input/input.txt: 1 file pushed, 0 skipped. 0.8 MB/s (30 bytes in 0.000s)

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="deeplabv3_resnet101"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="deeplabv3_resnet101_quant_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_Quant_DSP
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnHtp.so --input_list input.txt --retrieve_context ${QUANTIZED_MODEL_NAME}.serialized.bin --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:17244
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/deeplabv3_resnet101" (ignoring)
# WARNING: linker: Warning: unable to normalize "$/data/local/tmp/deeplabv3_resnet101" (ignoring)

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL shell
# export ONDEVICE_FOLDER="deeplabv3_resnet101"
# export device_path=/data/local/tmp/$ONDEVICE_FOLDER
# export LD_LIBRARY_PATH=$device_path
# export ADSP_LIBRARY_PATH="$device_path"
# export PATH=$PATH:$device_path
# export QUANTIZED_MODEL_NAME="deeplabv3_resnet101_quant_w8a8"
# cd $device_path
# export OUTPUT_FOLDER=OUTPUT_CPU
# cd /data/local/tmp/$ONDEVICE_FOLDER  &&
# ./qnn-net-run --backend libQnnCpu.so --input_list input.txt --model lib${QUANTIZED_MODEL_NAME}.so --output_dir $OUTPUT_FOLDER
# Out:
# qnn-net-run pid:17251

# %%
os.makedirs('output', exist_ok=True)

# %%
# %%bash
# rm -rf OUTPUT_Quant_DSP
# rm -rf OUTPUT_CPU

# %%
# %%bash
# export DEVICE_SHELL="adb -H $DEVICE_HOST -s $DEVICE_ID"
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_Quant_DSP output/OUTPUT_Quant_DSP
# $DEVICE_SHELL pull /data/local/tmp/$ONDEVICE_FOLDER/OUTPUT_CPU output/OUTPUT_CPU

# %%
def image_overlay(image, segmented_image):
    alpha = 1 # transparency for the original image
    beta = 0.8 # transparency for the segmentation map
    gamma = 0 # scalar added to each sum
    # print(image.size)
    # print(segmented_image.shape)
    segmented_image = cv2.cvtColor(segmented_image, cv2.COLOR_RGB2BGR)
    image = np.array(image)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cv2.addWeighted(image, alpha, segmented_image, beta, gamma, image)
    return image

# %%
import torchvision.transforms as transforms
crop_size = 400
transform = transforms.Compose([
    transforms.Resize((crop_size,crop_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
label_map = [
               (0, 0, 0),  # background
               (128, 0, 0), # aeroplane
               (0, 128, 0), # bicycle
               (128, 128, 0), # bird
               (0, 0, 128), # boat
               (128, 0, 128), # bottle
               (0, 128, 128), # bus 
               (128, 128, 128), # car
               (64, 0, 0), # cat
               (192, 0, 0), # chair
               (64, 128, 0), # cow
               (192, 128, 0), # dining table
               (64, 0, 128), # dog
               (192, 0, 128), # horse
               (64, 128, 128), # motorbike
               (192, 128, 128), # person
               (0, 64, 0), # potted plant
               (128, 64, 0), # sheep
               (0, 192, 0), # sofa
               (128, 192, 0), # train
               (0, 64, 128) # tv/monitor
]

# %%
def get_segment_labels(image, model, device):
    # transform the image to tensor and load into computation device
    image = transform(image).to(device)
    image = image.unsqueeze(0) # add a batch dimension
    outputs = model(image)
    return outputs

# %%
def draw_segmentation_map(outputs):
    labels = outputs.detach().cpu().numpy()
    # create Numpy arrays containing zeros
    # later to be used to fill them with respective red, green, and blue pixels
    red_map = np.zeros_like(labels).astype(np.uint8)
    green_map = np.zeros_like(labels).astype(np.uint8)
    blue_map = np.zeros_like(labels).astype(np.uint8)
    
    for label_num in range(0, len(label_map)):
        index = labels == label_num
        red_map[index] = np.array(label_map)[label_num, 0]
        green_map[index] = np.array(label_map)[label_num, 1]
        blue_map[index] = np.array(label_map)[label_num, 2]
        
    segmentation_map = np.stack([red_map, green_map, blue_map], axis=2)
    return segmentation_map

# %%
def ImageNames():
    inputlist = open('input/input.txt', 'r')
    Lines = inputlist.readlines()
    count = 0
    imageList = []
    for line in Lines:
        name = line.split("preproc_",1)[1]
        name = name.split('.')[0]
        imageList.append(name)
        count += 1
    return imageList
imageList = ImageNames()
print((imageList))

# %%
import torch
import numpy as np
device = torch.device('cpu')
model.eval()

# %%
os.makedirs('output/model_prediction', exist_ok=True)

# %%
image_dir = 'input/dataset/VOCdevkit/VOC2012/JPEGImages/'
from PIL import Image
import cv2
for i in range(0,len(imageList)):

    image = Image.open(image_dir+imageList[i]+'.jpg')
    # do forward pass and get the output dictionary
    image  = image.resize((crop_size,crop_size))
    # print(image.size)
    outputs = get_segment_labels(image, model, device)
    # get the data from the `out` key
    # outputs = outputs['out']
    # print(type(outputs))
    # print(outputs.shape)
    segmented_image = draw_segmentation_map(outputs[0])
    print(image.size)
    print(segmented_image.shape)
    final_image = image_overlay(image, segmented_image)
    # show the segmented image and save to disk
    # cv2.imshow('Segmented image', final_image)
    # cv2.waitKey(0)
    cv2.imwrite(f"output/model_prediction/{imageList[i]}.jpg", final_image)

# %%
def PostProc(img_path, out_path,i):
    res = np.fromfile(img_path, dtype="float32")
    res_reshape = res.reshape((1,400,400)).astype(np.float32)
    model_img = torch.from_numpy(res_reshape)
    segmented_image = draw_segmentation_map(model_img[0])
    image = Image.open(image_dir+imageList[i]+'.jpg')
    # do forward pass and get the output dictionary
    image  = image.resize((crop_size,crop_size))
    print(image.size)
    final_image = image_overlay(image, segmented_image)
    cv2.imwrite(f"{out_path}", final_image)

# %%
os.makedirs('output/test_results', exist_ok=True)
os.makedirs('output/test_results/32b_arm', exist_ok=True)
os.makedirs('output/test_results/8b_dsp', exist_ok=True)

# %%
test_images_dir = "output/OUTPUT_CPU/"
image_dir = 'input/dataset/VOCdevkit/VOC2012/JPEGImages/'
import cv2
import os
import numpy as np
import torch
from PIL import Image
for i in range(0,len(imageList)):
    img_path = os.path.join(test_images_dir, 'Result_')
    img_path = img_path+str(i)+'/_1073.raw'
    out_path = 'output/test_results/32b_arm/'+imageList[i]+'_prediction_32b_arm.png'
    PostProc(img_path, out_path,i)
    i = i +1

# %%
test_images_dir = "output/OUTPUT_Quant_DSP/"
for i in range(0,len(imageList)):
    img_path = os.path.join(test_images_dir, 'Result_')
    img_path = img_path+str(i)+'/_1073.raw'
    out_path = 'output/test_results/8b_dsp/'+imageList[i]+'_prediction_8b_dsp.png'
    PostProc(img_path, out_path,i)
    i = i +1

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(30, 100));
import cv2
for i in range(0, 5):
    
    original = cv2.imread('input/dataset/VOCdevkit/VOC2012/JPEGImages/'+imageList[i]+'.jpg')
    original = cv2.resize(original, (513,513))
    original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
    ax = fig.add_subplot(28,4,4*i+1);
    plt.imshow(original,cmap='gray');
    ax.set_title('original image\n');
    ax.axis('off');
    
    pth_inf = cv2.imread('output/model_prediction/'+imageList[i]+'.jpg')
    pth_inf = cv2.resize(pth_inf, (513,513))
    # pth_inf = cv2.cvtColor(pth_inf, cv2.COLOR_BGR2RGB)
    # pth_overlay = image_overlay(original, pth_inf)
    ax = fig.add_subplot(28,4,4*i+2);
    plt.imshow(pth_inf,cmap='gray');
    ax.set_title('pth output\n');
    ax.axis('off');


    arm_fp32= cv2.imread('output/test_results/32b_arm/'+imageList[i]+'_prediction_32b_arm.png')
    # arm_fp32 = cv2.cvtColor(arm_fp32, cv2.COLOR_BGR2RGB)
    # fp32_overlay = image_overlay(original, arm_fp32)
    arm_fp32 = cv2.resize(arm_fp32, (513,513))
    ax = fig.add_subplot(28,4,4*i+3);
    plt.imshow(arm_fp32,cmap='gray');
    ax.set_title('fp32 on ARM\n');
    ax.axis('off');

    dsp= cv2.imread('output/test_results/8b_dsp/'+imageList[i]+'_prediction_8b_dsp.png')
    # dsp_int8 = cv2.cvtColor(dsp_int8, cv2.COLOR_BGR2RGB)
    # int8_overlay = image_overlay(original, dsp_int8)
    # print(dsp)
    ax = fig.add_subplot(28,4,4*i+4);
    plt.imshow(dsp,cmap='gray');
    ax.set_title('int8 on DSP\n');
    ax.axis('off');
